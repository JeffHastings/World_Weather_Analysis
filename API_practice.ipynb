# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)
lat_lngs 

# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key

# %%
# Create a practice set of random latitude and longitude combinations.
x = [25.12903645, 25.92017388, 26.62509167, -59.98969384, 37.30571269]
y = [-67.59741259, 11.09532135, 74.84233102, -76.89176677, -61.13376282]
coordinates = zip(x, y)

# %%
# Use the tuple() function to display the latitude and longitude combinations.
for coordinate in coordinates:
    print(coordinate[0], coordinate[1])
# Out:
# 25.12903645 -67.59741259
# 25.92017388 11.09532135
# 26.62509167 74.84233102
# -59.98969384 -76.89176677
# 37.30571269 -61.13376282

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Use the citipy module to determine city based on latitude and longitude.
from citipy import citipy

# %%
# Use the tuple() function to display the latitude and longitude combinations.
for coordinate in coordinates:
    print(citipy.nearest_city(coordinate[0], coordinate[1]).city_name,
          citipy.nearest_city(coordinate[0], coordinate[1]).country_code)
# Out:
# albany au
# punta arenas cl
# saint george bm
# praia cv
# samusu ws
# rikitea pf
# jamestown sh
# sheridan us
# sinnamary gf
# dikson ru
# krasnogorskiy uz
# ushuaia ar
# tateyama jp
# tuktoyaktuk ca
# busselton au
# sola vu
# mahebourg mu
# fountain us
# vysokogornyy ru
# kapaa us
# geraldton au
# lebu cl
# maarianhamina fi
# saint george bm
# lagunas pe
# saint-philippe re
# albany au
# oranjemund na
# waddan ly
# chagda ru
# fort wellington gy
# talnakh ru
# norman wells ca
# punta arenas cl
# esperance au
# albany au
# torbay ca
# tabiauea ki
# butaritari ki
# auki sb
# belushya guba ru
# cidreira br
# ushuaia ar
# pisco pe
# norman wells ca
# ushuaia ar
# sitka us
# lorengau pg
# barentsburg sj
# tefe br
# ponta do sol cv
# norman wells ca
# krasnorechenskiy ru
# punta arenas cl
# vaini to
# palabuhanratu id
# aklavik ca
# broken hill au
# tuatapere nz
# busselton au
# taolanaro mg
# domoni km
# punta arenas cl
# atuona pf
# kaduna ng
# punta arenas cl
# skelleftea se
# caravelas br
# qaanaaq gl
# kruisfontein za
# esperance au
# yinchuan cn
# jamestown sh
# east london za
# rikitea pf
# clyde river ca
# belushya guba ru
# busselton au
# bethel us
# albany au
# bolungarvik is
# esperance au
# barrow us
# mahibadhoo mv
# busselton au
# ushuaia ar
# shimoda jp
# ponta do sol cv
# maniitsoq gl
# codrington ag
# ribeira grande pt
# wahran dz
# mataura pf
# cape town za
# busselton au
# naze jp
# chuy uy
# lavrentiya ru
# katsuura jp
# atuona pf
# rungata ki
# tuktoyaktuk ca
# busselton au
# novikovo ru
# erdenet mn
# college us
# sao felix do xingu br
# airai pw
# qaanaaq gl
# rikitea pf
# kawana waters au
# kodiak us
# westport nz
# kodiak us
# namatanai pg
# georgetown sh
# rikitea pf
# faanui pf
# punta arenas cl
# paamiut gl
# punta arenas cl
# wajima jp
# busselton au
# tasbuget kz
# punta arenas cl
# illoqqortoormiut gl
# the valley ai
# ushuaia ar
# poum nc
# luganville vu
# port alfred za
# longyearbyen sj
# qaanaaq gl
# sitka us
# dakar sn
# vardo no
# bogo cm
# worthington us
# khandyga ru
# cayenne gf
# puerto ayora ec
# albany au
# ushuaia ar
# buala sb
# georgetown sh
# rikitea pf
# rikitea pf
# butaritari ki
# vaini to
# arriana gr
# touros br
# ushuaia ar
# dianopolis br
# lagos pt
# bethel us
# samusu ws
# butaritari ki
# rikitea pf
# pevek ru
# ondangwa na
# leningradskiy ru
# avera pf
# puerto ayora ec
# ribeira grande pt
# upernavik gl
# tessalit ml
# mar del plata ar
# hilo us
# sharan af
# cayenne gf
# pevek ru
# saint anthony ca
# rikitea pf
# ushuaia ar
# ponta do sol cv
# balimo pg
# ushuaia ar
# hilo us
# kasra tn
# barentsburg sj
# albany au
# arlit ne
# ambunti pg
# castro cl
# jiroft ir
# brigantine us
# talah tn
# luderitz na
# viedma ar
# ushuaia ar
# bissau gw
# faanui pf
# hasaki jp
# jamestown sh
# barentsburg sj
# kapaa us
# belushya guba ru
# barentsburg sj
# korla cn
# rungata ki
# odweyne so
# kapaa us
# egvekinot ru
# laguna br
# hofn is
# grand river south east mu
# digby ca
# paamiut gl
# port-gentil ga
# clyde river ca
# lebu cl
# busselton au
# berkak no
# pontivy fr
# hobart au
# qaanaaq gl
# valparaiso cl
# rikitea pf
# le vauclin mq
# albany au
# chuy uy
# erzin ru
# hermanus za
# tahoua ne
# ushuaia ar
# albany au
# mar del plata ar
# hermanus za
# lavrentiya ru
# chapais ca
# hithadhoo mv
# rikitea pf
# lebu cl
# port alfred za
# kijang id
# castro cl
# albany au
# plered id
# albany au
# mataura pf
# tabou ci
# dogondoutchi ne
# caravelas br
# tuatapere nz
# alberton ca
# katherine au
# hilo us
# jardim br
# saint george bm
# pangody ru
# atuona pf
# hofn is
# bardiyah ly
# punta arenas cl
# sambava mg
# kamariotissa gr
# cabo san lucas mx
# georgetown sh
# ushuaia ar
# new norfolk au
# salalah om
# levelland us
# valley city us
# bandarbeyla so
# avera pf
# bredasdorp za
# staroshcherbinovskaya ru
# cape town za
# vaini to
# cherskiy ru
# aksarka ru
# sumbe ao
# provideniya ru
# bethel us
# sijunjung id
# thompson ca
# ancud cl
# cagayan de tawi-tawi ph
# ancud cl
# lompoc us
# clyde river ca
# vila velha br
# mataura pf
# griffith au
# buala sb
# airai pw
# durango us
# beyneu kz
# kurilsk ru
# borogontsy ru
# port alfred za
# barentsburg sj
# attawapiskat ca
# yellowknife ca
# koscierzyna pl
# taolanaro mg
# vicuna cl
# teguldet ru
# busselton au
# saint-philippe re
# tanjong karang my
# bluff nz
# tiksi ru
# taolanaro mg
# punta arenas cl
# hasaki jp
# ust-maya ru
# soledar ua
# sainte-suzanne re
# sungairaya id
# sao filipe cv
# chuy uy
# rikitea pf
# upernavik gl
# carnarvon au
# nikolskoye ru
# viligili mv
# kodiak us
# ushuaia ar
# carnarvon au
# saleaula ws
# warrnambool au
# chuy uy
# funtua ng
# dzhebariki-khaya ru
# cabedelo br
# yar-sale ru
# busselton au
# chaa-khol ru
# souillac mu
# loa janan id
# taltal cl
# busselton au
# namibe ao
# kamenskoye ru
# yuanping cn
# norman wells ca
# mar del plata ar
# east london za
# bluff nz
# puerto ayora ec
# kapaa us
# rikitea pf
# cape town za
# wuwei cn
# marystown ca
# sentyabrskiy ru
# illoqqortoormiut gl
# blagoyevo ru
# tuktoyaktuk ca
# barentsburg sj
# byron bay au
# ilulissat gl
# vaini to
# butaritari ki
# baykit ru
# nikolskoye ru
# port alfred za
# castro cl
# yaan cn
# abha sa
# laukaa fi
# castro cl
# umzimvubu za
# saint george bm
# souillac mu
# cabo san lucas mx
# kapaa us
# conde br
# avera pf
# mandalgovi mn
# vaini to
# miracema do tocantins br
# chokurdakh ru
# rikitea pf
# kurud in
# butaritari ki
# svetlyy ru
# tilichiki ru
# rikitea pf
# busselton au
# lebu cl
# namatanai pg
# jamestown sh
# prieska za
# ushuaia ar
# yulara au
# ekibastuz kz
# mataura pf
# busselton au
# aklavik ca
# busselton au
# coahuayana mx
# ushuaia ar
# goderich sl
# mataura pf
# saint george bm
# port alfred za
# inderborskiy kz
# kodiak us
# fortuna us
# saint-philippe re
# puerto ayora ec
# amderma ru
# cootamundra au
# busselton au
# matara lk
# arkhangelsk ru
# mataura pf
# shawinigan ca
# amderma ru
# arona es
# hobart au
# sinnamary gf
# tiksi ru
# sao joao da barra br
# bubaque gw
# sao filipe cv
# bin qirdan tn
# rikitea pf
# port macquarie au
# hobart au
# alyangula au
# nikolskoye ru
# tuktoyaktuk ca
# awbari ly
# hobart au
# punta arenas cl
# kamaishi jp
# torbay ca
# hirna et
# isangel vu
# busselton au
# avanigadda in
# nikolskoye ru
# bluff nz
# salalah om
# buchlovice cz
# cuamba mz
# san policarpo ph
# avarua ck
# bluff nz
# tromso no
# buala sb
# ushuaia ar
# khandbari np
# lagoa pt
# jamestown sh
# kalabo zm
# sentyabrskiy ru
# okhotsk ru
# rikitea pf
# tariba ve
# busselton au
# taoudenni ml
# mys shmidta ru
# mabama tz
# san quintin mx
# zhanakorgan kz
# butaritari ki
# sabang id
# avarua ck
# busselton au
# yellowknife ca
# clyde river ca
# bosaso so
# hobyo so
# mareeba au
# rikitea pf
# maarianhamina fi
# chapleau ca
# albany au
# kaniama cd
# darnah ly
# cidreira br
# egvekinot ru
# jamestown sh
# aromashevo ru
# albany au
# hermanus za
# veraval in
# jamestown sh
# mataura pf
# mataura pf
# ondo ng
# khatanga ru
# tulun ru
# chuy uy
# ushuaia ar
# hithadhoo mv
# beringovskiy ru
# dwarka in
# ozernovskiy ru
# mar del plata ar
# cherskiy ru
# dalnerechensk ru
# pueblo nuevo mx
# haines junction ca
# berberati cf
# porto novo cv
# beira mz
# cape town za
# toliary mg
# touros br
# sinnamary gf
# port augusta au
# cape town za
# albany au
# saldanha za
# busselton au
# saint-philippe re
# rikitea pf
# punta arenas cl
# shangrao cn
# hay river ca
# chokurdakh ru
# butaritari ki
# bluff nz
# mar del plata ar
# lata sb
# ushuaia ar
# cherskiy ru
# mataura pf
# taolanaro mg
# wabag pg
# hermanus za
# taolanaro mg
# khatanga ru
# taolanaro mg
# ushuaia ar
# atuona pf
# mataura pf
# amderma ru
# rantauprapat id
# tual id
# komsomolskiy ru
# qaanaaq gl
# tautira pf
# ilulissat gl
# bluff nz
# rungata ki
# labuhan id
# ushuaia ar
# yellowknife ca
# fomboni km
# port lavaca us
# otjiwarongo na
# port alfred za
# gorom-gorom bf
# codrington ag
# hilo us
# morant bay jm
# rikitea pf
# port alfred za
# rikitea pf
# bredasdorp za
# alekseyevsk ru
# ribeira grande pt
# east london za
# cape town za
# rikitea pf
# taolanaro mg
# khatanga ru
# ribeira grande pt
# sindor ru
# saint-philippe re
# abu kamal sy
# paamiut gl
# yellowknife ca
# sakaiminato jp
# san juan de uraba co
# longyearbyen sj
# ushuaia ar
# hithadhoo mv
# mar del plata ar
# chara ru
# albany au
# ipora br
# jamestown sh
# pevek ru
# rikitea pf
# ushuaia ar
# papasquiaro mx
# vaitupu wf
# airai pw
# manaus br
# hasaki jp
# huambo ao
# kapaa us
# busselton au
# grand river south east mu
# saint-philippe re
# kodiak us
# longkou cn
# broome au
# mehriz ir
# vaitupu wf
# taolanaro mg
# sao filipe cv
# attawapiskat ca
# ushuaia ar
# mataura pf
# pevek ru
# mataura pf
# mataura pf
# bluff nz
# kodiak us
# belushya guba ru
# camacha pt
# saskylakh ru
# ambilobe mg
# hobart au
# mys shmidta ru
# pedernales do
# hilo us
# kruisfontein za
# mys shmidta ru
# hobart au
# tabiauea ki
# yellowknife ca
# imeni zhelyabova ru
# punta arenas cl
# paradwip in
# krasnyye barrikady ru
# geraldton au
# mataura pf
# bluff nz
# atuona pf
# flinders au
# fukue jp
# samarai pg
# arraial do cabo br
# tuktoyaktuk ca
# yanam in
# georgetown sh
# tsihombe mg
# manzanillo mx
# sakakah sa
# atuona pf
# jamestown sh
# ponta do sol cv
# pemangkat id
# pankrushikha ru
# bluff nz
# le port re
# mataura pf
# punta arenas cl
# jamestown sh
# atuona pf
# high level ca
# qaanaaq gl
# ojinaga mx
# castro cl
# san patricio mx
# guerrero negro mx
# taolanaro mg
# kahului us
# qaanaaq gl
# avarua ck
# paamiut gl
# barbar sd
# bandarbeyla so
# chokurdakh ru
# port lincoln au
# atuona pf
# port hardy ca
# vaitupu wf
# mataura pf
# vaini to
# ocos gt
# beringovskiy ru
# misratah ly
# bluff nz
# codrington ag
# bethel us
# saleaula ws
# busselton au
# taolanaro mg
# kamenskoye ru
# mutsamudu km
# cape town za
# aripuana br
# new norfolk au
# asfi ma
# taonan cn
# atuona pf
# busselton au
# the valley ai
# bambous virieux mu
# egvekinot ru
# mnogovershinnyy ru
# bluff nz
# atuona pf
# touros br
# mys shmidta ru
# senmonorom kh
# sechura pe
# divnoye ru
# la macarena co
# dolbeau ca
# luderitz na
# muros es
# avarua ck
# north bend us
# nagamangala in
# saint-jean-de-la-ruelle fr
# bowling green us
# esperance au
# rikitea pf
# rikitea pf
# taolanaro mg
# coihaique cl
# barrow us
# new norfolk au
# rikitea pf
# mataura pf
# port lincoln au
# asyut eg
# hilo us
# busselton au
# staryy nadym ru
# strezhevoy ru
# harper lr
# amderma ru
# victoria sc
# coquimbo cl
# rikitea pf
# sabang id
# goderich sl
# saint-philippe re
# busselton au
# kon tum vn
# faanui pf
# inongo cd
# norman wells ca
# port blair in
# show low us
# qaqortoq gl
# kapaa us
# kapaa us
# upernavik gl
# stornoway gb
# husavik is
# punta arenas cl
# bratsk ru
# atuona pf
# port elizabeth za
# bluff nz
# lavrentiya ru
# tukrah ly
# tasiilaq gl
# kodiak us
# barentsburg sj
# taolanaro mg
# portland au
# dovolnoye ru
# avarua ck
# uniontown us
# saleaula ws
# vaini to
# bredasdorp za
# meyungs pw
# ushuaia ar
# yellowknife ca
# port blair in
# mosquera co
# sakakah sa
# mitchell us
# mogadishu so
# severo-kurilsk ru
# cabo san lucas mx
# east london za
# ushuaia ar
# amderma ru
# cantaura ve
# vaini to
# jamestown sh
# ushuaia ar
# faya td
# sentyabrskiy ru
# bairiki ki
# mahebourg mu
# atuona pf
# richards bay za
# talakan ru
# saint-francois gp
# rikitea pf
# butaritari ki
# kaitangata nz
# thompson ca
# sibi pk
# atuona pf
# leningradskiy ru
# victoria sc
# isangel vu
# kaka tm
# abu dhabi ae
# thompson ca
# tecoanapa mx
# punta arenas cl
# rikitea pf
# asfi ma
# vaini to
# punta arenas cl
# qaanaaq gl
# klaksvik fo
# seoul kr
# khandyga ru
# henties bay na
# busselton au
# port alfred za
# altay cn
# kaitangata nz
# kruisfontein za
# albany au
# hermanus za
# chuy uy
# yulara au
# grua no
# tabou ci
# torbay ca
# port alfred za
# sharqpur pk
# minsk by
# fairbanks us
# port elizabeth za
# tiksi ru
# mount gambier au
# vaini to
# chernyshevskiy ru
# saleaula ws
# berlevag no
# chase ca
# puerto ayora ec
# hobart au
# ushuaia ar
# shelburne ca
# yellowknife ca
# mutoko zw
# tessalit ml
# busselton au
# tasiilaq gl
# price us
# constitucion cl
# ust-bolsheretsk ru
# kaitangata nz
# touros br
# ushuaia ar
# nhamunda br
# samarai pg
# rikitea pf
# zhigansk ru
# kpandae gh
# mahebourg mu
# taolanaro mg
# hobart au
# saint-philippe re
# rikitea pf
# illoqqortoormiut gl
# fort nelson ca
# sinnamary gf
# mataura pf
# khatanga ru
# kodiak us
# jasper ca
# mataura pf
# vaini to
# leningradskiy ru
# barrow us
# ushuaia ar
# tilichiki ru
# taolanaro mg
# albany au
# tebingtinggi id
# beira mz
# ramhormoz ir
# karratha au
# ushuaia ar
# phrai bung th
# atuona pf
# matara lk
# te anau nz
# port alfred za
# hobart au
# mataura pf
# harrisonburg us
# taolanaro mg
# punta arenas cl
# ushuaia ar
# iskateley ru
# gao ml
# college us
# nanortalik gl
# georgetown sh
# punta arenas cl
# mataura pf
# ushuaia ar
# nikolskoye ru
# atuona pf
# kavieng pg
# hay river ca
# ponta do sol cv
# luanda ao
# bluff nz
# mataura pf
# gwadar pk
# melbourne au
# hilo us
# santa cruz de la palma es
# mataura pf
# punta arenas cl
# faanui pf
# hobart au
# rikitea pf
# hare bay ca
# puerto ayora ec
# robertsport lr
# paamiut gl
# saldanha za
# kyshtovka ru
# nikolskoye ru
# ushuaia ar
# atuona pf
# matara lk
# albany au
# langsa id
# rikitea pf
# yellowknife ca
# yamada jp
# grand centre ca
# kahului us
# punta arenas cl
# tuktoyaktuk ca
# chapais ca
# albany au
# terney ru
# vaini to
# vaini to
# port blair in
# lodja cd
# salinas ec
# mys shmidta ru
# hobart au
# sibolga id
# rikitea pf
# tura ru
# ushuaia ar
# bredy ru
# georgetown sh
# bathsheba bb
# cairns au
# barrow us
# georgetown sh
# saint-philippe re
# esmeraldas ec
# taolanaro mg
# rikitea pf
# jak hu
# yarmouth ca
# nizhneyansk ru
# naze jp
# busselton au
# ushuaia ar
# saint-philippe re
# khatanga ru
# wagar sd
# mosty u jablunkova cz
# halalo wf
# takoradi gh
# abha sa
# airai pw
# rikitea pf
# geraldton au
# mataura pf
# mataura pf
# shingu jp
# poya nc
# hermanus za
# constantine dz
# vao nc
# rikitea pf
# praia da vitoria pt
# ilulissat gl
# ellisras za
# lavrentiya ru
# nara ml
# broken hill au
# cockburn town bs
# nizhneyansk ru
# kapaa us
# olafsvik is
# ushuaia ar
# ribeira grande pt
# qaanaaq gl
# kodiak us
# cherskiy ru
# calama cl
# maragogi br
# rio grande br
# sentyabrskiy ru
# mataura pf
# cape town za
# coquimbo cl
# attawapiskat ca
# lorengau pg
# rikitea pf
# hasaki jp
# ancud cl
# mangrol in
# busselton au
# georgetown sh
# bethel us
# saleaula ws
# maceio br
# ushuaia ar
# tabukiniberu ki
# takoradi gh
# puerto ayora ec
# punta arenas cl
# tasiilaq gl
# miri my
# izumo jp
# necochea ar
# tsihombe mg
# bethel us
# bandarbeyla so
# belushya guba ru
# punta arenas cl
# barrow us
# upernavik gl
# lebu cl
# hithadhoo mv
# marsh harbour bs
# busselton au
# punta arenas cl
# qaanaaq gl
# sao filipe cv
# yellowknife ca
# avera pf
# abu kamal sy
# taolanaro mg
# port alfred za
# port hedland au
# tessalit ml
# atuona pf
# garden city us
# new norfolk au
# bluff nz
# lac du bonnet ca
# cape town za
# bredasdorp za
# hermanus za
# hilo us
# nador ma
# utete tz
# hovd mn
# yumen cn
# srednekolymsk ru
# airai pw
# grand river south east mu
# iquitos pe
# port elizabeth za
# thompson ca
# lazurne ua
# muros es
# kosa ru
# cape town za
# itarema br
# lebu cl
# vardo no
# svarstad no
# ushuaia ar
# provideniya ru
# rikitea pf
# tautira pf
# torbay ca
# georgetown sh
# cherskiy ru
# punta arenas cl
# bauchi ng
# saskylakh ru
# tura ru
# tasiilaq gl
# bac lieu vn
# sola vu
# vaini to
# pisco pe
# meulaboh id
# thompson ca
# rikitea pf
# bluff nz
# atuona pf
# georgetown sh
# puerto ayora ec
# tuktoyaktuk ca
# teya ru
# ushuaia ar
# mount pleasant us
# kishi ng
# yellowknife ca
# tiksi ru
# cam ranh vn
# ahipara nz
# katsuura jp
# lompoc us
# paradwip in
# nikolskoye ru
# punta arenas cl
# avarua ck
# bayanday ru
# bluff nz
# jiangyou cn
# vaini to
# dunedin nz
# guangyuan cn
# kavieng pg
# sentyabrskiy ru
# comodoro rivadavia ar
# lavrentiya ru
# cape town za
# bengkulu id
# hai phong vn
# zhezkazgan kz
# punta arenas cl
# yellowknife ca
# beringovskiy ru
# nanakuli us
# pirgos gr
# constitucion mx
# maceio br
# murray bridge au
# vao nc
# itarema br
# mecca sa
# castro cl
# jamestown sh
# ushuaia ar
# mahebourg mu
# ilulissat gl
# yamada jp
# kapaa us
# rocha uy
# ponta do sol pt
# fukue jp
# sinnamary gf
# hobart au
# qaanaaq gl
# sao filipe cv
# kibala ao
# punta arenas cl
# waingapu id
# camana pe
# tautira pf
# bethanien na
# nizhneyansk ru
# vaini to
# taoudenni ml
# norman wells ca
# mahebourg mu
# tilichiki ru
# kondagaon in
# punta arenas cl
# victoria sc
# ushuaia ar
# arraial do cabo br
# bluff nz
# ushuaia ar
# ushuaia ar
# borger us
# rikitea pf
# tiksi ru
# esperance au
# san policarpo ph
# rikitea pf
# najran sa
# belushya guba ru
# george za
# ceres za
# kapaa us
# saldanha za
# puerto ayora ec
# san quintin mx
# fortuna us
# vaitupu wf
# illoqqortoormiut gl
# price us
# grand river south east mu
# puerto ayora ec
# nouadhibou mr
# palimbang ph
# rikitea pf
# shubarkuduk kz
# port elizabeth za
# puerto ayora ec
# thompson ca
# port alfred za
# spring valley us
# kruisfontein za
# mahibadhoo mv
# arraial do cabo br
# hermanus za
# port alfred za
# albany au
# kondinskoye ru
# petropavlovsk-kamchatskiy ru
# atuona pf
# georgetown sh
# vaini to
# ko samui th
# busselton au
# ixtapa mx
# castro cl
# rikitea pf
# civitanova marche it
# puerto ayora ec
# chagda ru
# bluff nz
# carnarvon au
# east london za
# punta arenas cl
# bubaque gw
# hermanus za
# hermanus za
# port alfred za
# hobart au
# hilo us
# yellowknife ca
# ucluelet ca
# malinyi tz
# zyryanka ru
# butaritari ki
# avarua ck
# taolanaro mg
# ushuaia ar
# chokurdakh ru
# mys shmidta ru
# qaanaaq gl
# albany au
# ahipara nz
# rikitea pf
# vaini to
# ahuimanu us
# pakxan la
# butaritari ki
# cape town za
# makaha us
# wonthaggi au
# port lincoln au
# katsuura jp
# ushuaia ar
# ponta do sol cv
# hofn is
# puerto ayora ec
# rikitea pf
# sault sainte marie ca
# busselton au
# buala sb
# barrow us
# hobart au
# guerrero negro mx
# ust-nera ru
# hermanus za
# hermanus za
# coquimbo cl
# jamestown sh
# kahului us
# altay cn
# sao joao da barra br
# vaini to
# busselton au
# aquidaba br
# te anau nz
# atuona pf
# mogadishu so
# kapaa us
# bluff nz
# vaitupu wf
# grand river south east mu
# bhawana pk
# tuktoyaktuk ca
# lavrentiya ru
# ushuaia ar
# busselton au
# yellowknife ca
# cape town za
# lebu cl
# ushuaia ar
# sinnamary gf
# rikitea pf
# nanortalik gl
# geraldton au
# avarua ck
# jalu ly
# portland au
# yellowknife ca
# longyearbyen sj
# ushuaia ar
# karaul ru
# rikitea pf
# dolzhanskaya ru
# albany au
# bredasdorp za
# palabuhanratu id
# kavieng pg
# tasiilaq gl
# barcelos br
# puerto ayora ec
# ushuaia ar
# puerto ayora ec
# verkhnevilyuysk ru
# ouargaye bf
# belushya guba ru
# mutoko zw
# maragogi br
# kaitangata nz
# nikolskoye ru
# vaini to
# qaqortoq gl
# amudalavalasa in
# ushuaia ar
# rikitea pf
# miraflores co
# nabire id
# guerrero negro mx
# mys shmidta ru
# slonim by
# saldanha za
# salinopolis br
# kilindoni tz
# georgetown sh
# lagoa pt
# port alfred za
# tres arroyos ar
# port alfred za
# illoqqortoormiut gl
# hami cn
# zemes ro
# teahupoo pf
# nanortalik gl
# joshimath in
# busselton au
# hermanus za
# fortuna us
# batticaloa lk
# mys shmidta ru
# namibe ao
# mataura pf
# hermanus za
# mataura pf
# ostrovnoy ru
# pringsewu id
# vestmanna fo
# avarua ck
# yellowknife ca
# souillac mu
# atakpame tg
# sinnamary gf
# camacha pt
# albany au
# east angus ca
# punta arenas cl
# cape town za
# punta arenas cl
# te anau nz
# bluff nz
# gat ly
# camacha pt
# new norfolk au
# paramonga pe
# cherskiy ru
# ambulu id
# makasar id
# bredasdorp za
# bredasdorp za
# tandag ph
# coquimbo cl
# johi pk
# katsiveli ua
# roswell us
# hithadhoo mv
# qaqortoq gl
# kharan pk
# bethel us
# yellowknife ca
# butaritari ki
# tual id
# halalo wf
# buchanan lr
# amambai br
# kintampo gh
# cantagalo br
# cape town za
# iquique cl
# sorland no
# kodiak us
# tsienyane bw
# ushuaia ar
# pedasi pa
# chikoy ru
# hilo us
# klaksvik fo
# ust-nera ru
# hilo us
# mataura pf
# mangrol in
# jumla np
# surt ly
# rikitea pf
# alwar in
# hermanus za
# nikolskoye ru
# strelka ru
# avarua ck
# leningradskiy ru
# maniwaki ca
# mataura pf
# vodnyy ru
# hermanus za
# joshimath in
# sheregesh ru
# grand river south east mu
# necochea ar
# mataura pf
# cedar city us
# punta arenas cl
# vao nc
# port elizabeth za
# santa rosa ar
# paita pe
# carnarvon au
# surab pk
# georgetown sh
# rongcheng cn
# rikitea pf
# port lincoln au
# barrow us
# qaanaaq gl
# ushuaia ar
# bluff nz
# albany au
# tuktoyaktuk ca
# khilok ru
# rikitea pf
# port elizabeth za
# beeville us
# cape town za
# hobart au
# barrow us
# rikitea pf
# punta arenas cl
# omboue ga
# dunedin nz
# rikitea pf
# ancud cl
# kapaa us
# adrar dz
# khatanga ru
# yeppoon au
# dikson ru
# lagos pt
# punta arenas cl
# trelew ar
# port alfred za
# port alfred za
# rosetta eg
# thompson ca
# vaini to
# barrow us
# aksarka ru
# vaini to
# umzimvubu za
# kapaa us
# rio gallegos ar
# new norfolk au
# ribeira grande pt
# mataura pf
# albany au
# katsuura jp
# illoqqortoormiut gl
# dikson ru
# sassandra ci
# bengkulu id
# taolanaro mg
# severo-kurilsk ru
# port elizabeth za
# kapaa us
# atuona pf
# saldanha za
# hermanus za
# vestmannaeyjar is
# busselton au
# mataura pf
# atuona pf
# nikolskoye ru
# sentyabrskiy ru
# port elizabeth za
# marcona pe
# balad iq
# makakilo city us
# esperance au

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
print(url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=fcd05be0edd6fd91056ed9f140fddd5a

# %%
# Create an endpoint URL for a city.
city_url = url + "&q=" + "Boston"
print(city_url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=fcd05be0edd6fd91056ed9f140fddd5a&q=Boston

# %%
# Make a 'Get' request for the city weather.
city_weather = requests.get(city_url)
city_weather
# Out:
# <Response [200]>

# %%
city_weather.status_code
# Out:
# 200

# %%
# Create an endpoint URL for a city.
city_url = url + "&q=" + "Bston"
city_weather = requests.get(city_url)
city_weather
# Out:
# <Response [404]>

# %%
# Create an endpoint URL for a city.
city_url = url + "&q=" + "Boston"
city_weather = requests.get(city_url)
city_weather
# Out:
# <Response [200]>

# %%
# Get the text of the 'Get' request.
city_weather.text
# Out:
# '{"coord":{"lon":-71.06,"lat":42.36},"weather":[{"id":804,"main":"Clouds","description":"overcast clouds","icon":"04d"}],"base":"stations","main":{"temp":80.24,"feels_like":82.69,"temp_min":75.99,"temp_max":84.99,"pressure":1016,"humidity":74},"wind":{"speed":10.29,"deg":110,"gust":17.22},"clouds":{"all":100},"dt":1594407043,"sys":{"type":1,"id":4967,"country":"US","sunrise":1594372624,"sunset":1594426912},"timezone":-14400,"id":4930956,"name":"Boston","cod":200}'

# %%
# Get the JSON text of the 'Get' request.
city_weather.json()
# Out:
# {'coord': {'lon': -71.06, 'lat': 42.36},
#  'weather': [{'id': 804,
#    'main': 'Clouds',
#    'description': 'overcast clouds',
#    'icon': '04d'}],
#  'base': 'stations',
#  'main': {'temp': 80.24,
#   'feels_like': 82.69,
#   'temp_min': 75.99,
#   'temp_max': 84.99,
#   'pressure': 1016,
#   'humidity': 74},
#  'wind': {'speed': 10.29, 'deg': 110, 'gust': 17.22},
#  'clouds': {'all': 100},
#  'dt': 1594407043,
#  'sys': {'type': 1,
#   'id': 4967,
#   'country': 'US',
#   'sunrise': 1594372624,
#   'sunset': 1594426912},
#  'timezone': -14400,
#  'id': 4930956,
#  'name': 'Boston',
#  'cod': 200}

# %%
# Create an endpoint URL for a city.
city_url = url + "&q=" + "Boston"
city_weather = requests.get(city_url)
if city_weather.status_code == 200:
    print(f"City Weather found.")
else:
    print(f"City weather not found.")
# Out:
# City Weather found.

# %%
# Create an endpoint URL for a city.
city_url = url + "&q=" + "Bston"
city_weather = requests.get(city_url)
if city_weather.json():
    print(f"City Weather found.")
else:
    print(f"City weather not found.")
# Out:
# City Weather found.

# %%
# Create an endpoint URL for a city.
city_url = url + "&q=" + "Boston"
city_weather = requests.get(city_url)
city_weather.json()
# Out:
# {'coord': {'lon': -71.06, 'lat': 42.36},
#  'weather': [{'id': 804,
#    'main': 'Clouds',
#    'description': 'overcast clouds',
#    'icon': '04d'}],
#  'base': 'stations',
#  'main': {'temp': 80.24,
#   'feels_like': 82.69,
#   'temp_min': 75.99,
#   'temp_max': 84.99,
#   'pressure': 1016,
#   'humidity': 74},
#  'wind': {'speed': 10.29, 'deg': 110, 'gust': 17.22},
#  'clouds': {'all': 100},
#  'dt': 1594407043,
#  'sys': {'type': 1,
#   'id': 4967,
#   'country': 'US',
#   'sunrise': 1594372624,
#   'sunset': 1594426912},
#  'timezone': -14400,
#  'id': 4930956,
#  'name': 'Boston',
#  'cod': 200}

# %%
# Get the JSON data.
boston_data = city_weather.json()

# %%
boston_data['sys']
# Out:
# {'type': 1,
#  'id': 4967,
#  'country': 'US',
#  'sunrise': 1594372624,
#  'sunset': 1594426912}

# %%
boston_data['sys']['country']
# Out:
# 'US'

# %%
boston_data["dt"]
# Out:
# 1594407043

# %%
lat = boston_data["coord"]["lat"]
lng = boston_data["coord"]["lon"]
max_temp = boston_data["main"]["temp_max"]
humidity = boston_data["main"]["humidity"]
clouds = boston_data["clouds"]["all"]
wind = boston_data["wind"]["speed"]
print(lat, lng, max_temp, humidity, clouds, wind)
# Out:
# 42.36 -71.06 84.99 74 100 10.29

# %%
# Import the datetime module from the datetime library.
from datetime import datetime
# Get the date from the JSON file.
date = boston_data["dt"]
# Convert the UTC date to a date format with year, month, day, hours, minutes, and seconds.
datetime.utcfromtimestamp(date)
# Out:
# datetime.datetime(2020, 7, 10, 18, 50, 43)

# %%
datetime.utcfromtimestamp(date).strftime('%Y-%m-%d %H:%M:%S')
# Out:
# '2020-07-10 18:50:43'

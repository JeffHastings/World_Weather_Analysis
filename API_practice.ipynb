# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# Add Matplotlib inline magic command
# %matplotlib inline

# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)
lat_lngs 

# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key

# %%
# Create a practice set of random latitude and longitude combinations.
x = [25.12903645, 25.92017388, 26.62509167, -59.98969384, 37.30571269]
y = [-67.59741259, 11.09532135, 74.84233102, -76.89176677, -61.13376282]
coordinates = zip(x, y)

# %%
# Use the tuple() function to display the latitude and longitude combinations.
for coordinate in coordinates:
    print(coordinate[0], coordinate[1])
# Out:
# 25.12903645 -67.59741259
# 25.92017388 11.09532135
# 26.62509167 74.84233102
# -59.98969384 -76.89176677
# 37.30571269 -61.13376282

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Use the citipy module to determine city based on latitude and longitude.
from citipy import citipy

# %%
# Use the tuple() function to display the latitude and longitude combinations.
for coordinate in coordinates:
    print(citipy.nearest_city(coordinate[0], coordinate[1]).city_name,
          citipy.nearest_city(coordinate[0], coordinate[1]).country_code)
# Out:
# nefteyugansk ru
# vao nc
# jamestown sh
# gimli ca
# kieta pg
# port alfred za
# cape town za
# upernavik gl
# hilo us
# labuhan id
# nome us
# nikolskoye ru
# bulolo pg
# bengkulu id
# clyde river ca
# hambantota lk
# aswan eg
# hithadhoo mv
# liverpool ca
# burnie au
# kapaa us
# barrow us
# arraial do cabo br
# coihaique cl
# hithadhoo mv
# cape town za
# kapaa us
# conceicao do araguaia br
# mataura pf
# punta arenas cl
# severo-kurilsk ru
# dikson ru
# puerto escondido mx
# airai pw
# comodoro rivadavia ar
# vaini to
# rikitea pf
# ushuaia ar
# victoria sc
# bakel sn
# kapaa us
# bredasdorp za
# carnarvon au
# odemis tr
# sao filipe cv
# kodiak us
# san andres co
# butaritari ki
# asau tv
# ntungamo ug
# guerrero negro mx
# kaitangata nz
# malakal sd
# gat ly
# gijon es
# ballina au
# progreso mx
# abu dhabi ae
# hermanus za
# whitehorse ca
# souillac mu
# atuona pf
# castro cl
# mataura pf
# punta arenas cl
# san miguel pe
# rikitea pf
# rikitea pf
# yellowknife ca
# qaanaaq gl
# rypefjord no
# albany au
# taoudenni ml
# butaritari ki
# lavrentiya ru
# el alto pe
# lolua tv
# butaritari ki
# new norfolk au
# east london za
# bluff nz
# wilmington us
# agadez ne
# taywarah af
# maldonado uy
# hamilton bm
# tabriz ir
# pevek ru
# tuktoyaktuk ca
# luderitz na
# paamiut gl
# watertown us
# huarmey pe
# nikolskoye ru
# mataura pf
# cabo san lucas mx
# illoqqortoormiut gl
# jalu ly
# punta arenas cl
# jamestown sh
# cabra ph
# bluff nz
# broken hill au
# port hedland au
# isangel vu
# sinnamary gf
# pisco pe
# qaanaaq gl
# hirara jp
# atuona pf
# hobart au
# faanui pf
# sokolo ml
# cherskiy ru
# ilulissat gl
# mount isa au
# tahoua ne
# vaini to
# hilo us
# mahebourg mu
# ushuaia ar
# saint-philippe re
# yumen cn
# urusha ru
# young uy
# sitka us
# avarua ck
# punta arenas cl
# namibe ao
# meyungs pw
# butaritari ki
# synya ru
# atuona pf
# marawi sd
# mys shmidta ru
# taolanaro mg
# port lincoln au
# hue vn
# nanortalik gl
# meybod ir
# albany au
# yulara au
# east london za
# rikitea pf
# samusu ws
# barroualie vc
# mataura pf
# dhidhdhoo mv
# savonlinna fi
# urucara br
# illoqqortoormiut gl
# kibara tz
# poum nc
# sorong id
# nikolskoye ru
# tautira pf
# peniche pt
# vardo no
# rikitea pf
# mar del plata ar
# taolanaro mg
# maniitsoq gl
# atuona pf
# illoqqortoormiut gl
# belushya guba ru
# mehamn no
# mosquera co
# atar mr
# amderma ru
# luderitz na
# saleaula ws
# dalvik is
# yuksekova tr
# azul ar
# plettenberg bay za
# vaini to
# fairlie nz
# rikitea pf
# mega et
# ushuaia ar
# chokurdakh ru
# vila do maio cv
# egvekinot ru
# bonavista ca
# mataura pf
# rikitea pf
# cape town za
# sao filipe cv
# bredasdorp za
# puerto ayora ec
# lebu cl
# tuktoyaktuk ca
# taolanaro mg
# barrow us
# busselton au
# westport nz
# avarua ck
# longyearbyen sj
# vestmannaeyjar is
# winnemucca us
# hobart au
# hermanus za
# zhigansk ru
# illoqqortoormiut gl
# illoqqortoormiut gl
# saint-pierre mq
# mar del plata ar
# kamina cd
# busselton au
# cherskiy ru
# homer us
# seoul kr
# esperance au
# butaritari ki
# sorland no
# narsaq gl
# kununurra au
# saskylakh ru
# guiratinga br
# ribeira grande pt
# dubreka gn
# puerto del rosario es
# leningradskiy ru
# chumikan ru
# punta arenas cl
# barentsburg sj
# acapulco mx
# tuatapere nz
# foki ru
# kruisfontein za
# kiruna se
# bluff nz
# vechelde de
# tazovskiy ru
# hobart au
# castro cl
# rikitea pf
# vestmanna fo
# butaritari ki
# longyearbyen sj
# rikitea pf
# tiksi ru
# mataura pf
# itarana br
# albany au
# puerto padre cu
# butaritari ki
# butaritari ki
# luau ao
# jamestown sh
# albany au
# saskylakh ru
# taolanaro mg
# yulara au
# ribeira grande pt
# hithadhoo mv
# victoria sc
# jamestown sh
# adzhamka ua
# mahebourg mu
# norman wells ca
# tammisaari fi
# salinopolis br
# sentyabrskiy ru
# west bay ky
# rampur in
# hobart au
# busselton au
# mataura pf
# aasiaat gl
# hobart au
# codogno it
# maragogi br
# bereda so
# kaitangata nz
# albany au
# hithadhoo mv
# mataura pf
# liberal us
# qaanaaq gl
# todos santos mx
# kahului us
# atuona pf
# samana do
# vaini to
# hofn is
# thompson ca
# usinsk ru
# roseburg us
# jamestown sh
# busselton au
# ushuaia ar
# guerrero negro mx
# punta arenas cl
# thompson ca
# kapaa us
# provideniya ru
# mar del plata ar
# huilong cn
# yellowknife ca
# punta arenas cl
# christchurch nz
# fortuna us
# provideniya ru
# ilulissat gl
# sentyabrskiy ru
# nikolskoye ru
# jamestown sh
# nikolskoye ru
# ilulissat gl
# hermanus za
# arraial do cabo br
# la roda es
# vestmannaeyjar is
# avarua ck
# hermanus za
# casablanca ma
# cherskiy ru
# bluff nz
# manta ec
# illoqqortoormiut gl
# ulaangom mn
# taolanaro mg
# qaanaaq gl
# hvide sande dk
# jamestown sh
# broome au
# hilo us
# hobart au
# khatanga ru
# yellowknife ca
# tautira pf
# georgetown sh
# takoradi gh
# talnakh ru
# cape town za
# kodiak us
# khatanga ru
# ust-ishim ru
# vigrestad no
# lyngseidet no
# barrow us
# lagoa pt
# faya td
# provideniya ru
# hilo us
# bimbo cf
# barrow us
# ostrovnoy ru
# lorengau pg
# semme sn
# iberia pe
# sar-e pul af
# attawapiskat ca
# casablanca ma
# loughton gb
# camacha pt
# bargal so
# zhezkazgan kz
# yulara au
# punta arenas cl
# tokzar af
# mataura pf
# nikolskoye ru
# albany au
# albany au
# rikitea pf
# kaitangata nz
# butaritari ki
# karakendzha tj
# atuona pf
# ribeira grande pt
# severo-kurilsk ru
# kamenka ru
# port alfred za
# kruisfontein za
# cape town za
# kapaa us
# ewa beach us
# pacific grove us
# punta arenas cl
# atikokan ca
# auki sb
# albany au
# cabra ph
# arona es
# clyde river ca
# torbay ca
# punta arenas cl
# hilo us
# sabla bg
# khatanga ru
# labuhan id
# flin flon ca
# mataura pf
# paramonga pe
# hilo us
# padang id
# mayumba ga
# nokha in
# rikitea pf
# eyl so
# perm ru
# vaini to
# quatis br
# saint-leu re
# evensk ru
# puerto penasco mx
# rikitea pf
# busselton au
# nizhneyansk ru
# arlit ne
# bambous virieux mu
# roswell us
# mar del plata ar
# chokurdakh ru
# toliary mg
# laguna br
# sorong id
# mataura pf
# avarua ck
# ushuaia ar
# nikolskoye ru
# rikitea pf
# chapais ca
# bengkulu id
# fare pf
# port alfred za
# mar del plata ar
# alofi nu
# vestmannaeyjar is
# saldanha za
# taolanaro mg
# ngukurr au
# dikson ru
# tasiilaq gl
# san jeronimo mx
# beyneu kz
# ushuaia ar
# faanui pf
# pucallpa pe
# albany au
# jiwani pk
# taolanaro mg
# northam au
# rikitea pf
# port alfred za
# taolanaro mg
# hilo us
# illoqqortoormiut gl
# oyem ga
# inhambane mz
# yakima us
# pijijiapan mx
# cape town za
# yellowknife ca
# camacha pt
# yanchukan ru
# barentsburg sj
# sitka us
# punta arenas cl
# bengkulu id
# taolanaro mg
# albany au
# kodiak us
# nantucket us
# ponta do sol cv
# wundanyi ke
# greenville us
# busselton au
# jamestown sh
# hami cn
# talnakh ru
# busselton au
# clyde river ca
# tiksi ru
# hasaki jp
# san patricio mx
# minsk by
# puro ph
# mataura pf
# sentyabrskiy ru
# pakala in
# barrow us
# ushuaia ar
# mataura pf
# barrow us
# port elizabeth za
# oriximina br
# otane nz
# new norfolk au
# bredasdorp za
# adet et
# hilo us
# new norfolk au
# avarua ck
# geraldton au
# busselton au
# ruatoria nz
# fortuna us
# hay river ca
# hualmay pe
# castro cl
# tasiilaq gl
# tuktoyaktuk ca
# baruun-urt mn
# safranbolu tr
# cape town za
# quelimane mz
# rikitea pf
# caravelas br
# busselton au
# jamestown sh
# tumannyy ru
# sorvag fo
# ushuaia ar
# taolanaro mg
# hermanus za
# jamestown sh
# lebu cl
# ribeira grande pt
# tasbuget kz
# matameye ne
# kismayo so
# yellowknife ca
# talnakh ru
# samusu ws
# hermanus za
# rikitea pf
# punta arenas cl
# trofaiach at
# saint-philippe re
# muli mv
# umm lajj sa
# dali cn
# pangnirtung ca
# ushuaia ar
# taolanaro mg
# kahului us
# polunochnoye ru
# bonthe sl
# vanimo pg
# dingle ie
# vanavara ru
# hithadhoo mv
# rikitea pf
# wewak pg
# santa isabel do rio negro br
# ancud cl
# mys shmidta ru
# athabasca ca
# saskylakh ru
# puerto ayora ec
# mar del plata ar
# butaritari ki
# cherskiy ru
# rikitea pf
# upernavik gl
# namibe ao
# punta arenas cl
# albany au
# loucovice cz
# provideniya ru
# coahuayana mx
# rikitea pf
# mananara mg
# busselton au
# ushuaia ar
# punta arenas cl
# saskylakh ru
# tasiilaq gl
# ponta do sol cv
# mar del plata ar
# east london za
# illoqqortoormiut gl
# punta arenas cl
# rikitea pf
# riberalta bo
# saint-junien fr
# san antonio cl
# punta arenas cl
# satitoa ws
# camana pe
# ushuaia ar
# thompson ca
# sechura pe
# albany au
# provideniya ru
# milkovo ru
# meadow lake ca
# puerto ayora ec
# floro no
# nome us
# taolanaro mg
# rubiataba br
# touros br
# coquimbo cl
# atuona pf
# quatre cocos mu
# bambanglipuro id
# tiksi ru
# belushya guba ru
# mataura pf
# ilulissat gl
# touros br
# hermanus za
# kirakira sb
# kruisfontein za
# zhezkazgan kz
# belushya guba ru
# isangel vu
# tungkang tw
# hobart au
# general roca ar
# illoqqortoormiut gl
# rikitea pf
# portovelo ec
# navolato mx
# puerto madryn ar
# atuona pf
# tiksi ru
# xian cn
# burnie au
# bela pk
# tuktoyaktuk ca
# riverton us
# ushuaia ar
# guiratinga br
# hithadhoo mv
# athabasca ca
# atuona pf
# butaritari ki
# saint-philippe re
# clyde river ca
# longyearbyen sj
# krasnyy yar ru
# diamantino br
# sedelnikovo ru
# storsteinnes no
# tidore id
# illoqqortoormiut gl
# hilo us
# havre-saint-pierre ca
# hobyo so
# clyde river ca
# bredasdorp za
# privolzhye ru
# albany au
# rikitea pf
# kahului us
# misratah ly
# padang id
# bambous virieux mu
# busselton au
# kavaratti in
# sabang id
# rikitea pf
# esperance au
# sorland no
# faanui pf
# maneadero mx
# montepuez mz
# agara ge
# tomigusuku jp
# araxa br
# vaini to
# bluff nz
# benjamin constant br
# sola vu
# lompoc us
# sakaraha mg
# cape town za
# zharkent kz
# petropavlovsk-kamchatskiy ru
# ushuaia ar
# punta arenas cl
# cape town za
# carnarvon au
# rikitea pf
# tubruq ly
# rikitea pf
# saint-philippe re
# quelimane mz
# butaritari ki
# chapais ca
# tuktoyaktuk ca
# haines junction ca
# faanui pf
# alta floresta br
# firozpur jhirka in
# mataura pf
# grand river south east mu
# saint-augustin ca
# thompson ca
# lorengau pg
# stolin by
# purranque cl
# nanortalik gl
# cape town za
# torbay ca
# sinnamary gf
# yumen cn
# esperance au
# dikson ru
# ostrovnoy ru
# hermanus za
# mar del plata ar
# ilinsko-podomskoye ru
# busselton au
# eureka us
# new norfolk au
# rikitea pf
# nikolskoye ru
# nikolskoye ru
# punta arenas cl
# taburi ph
# victoria sc
# rikitea pf
# saint-philippe re
# belushya guba ru
# faanui pf
# saravena co
# mys shmidta ru
# ahuimanu us
# san pedro ar
# nikolskoye ru
# atuona pf
# orikhove ua
# santa maria cv
# mataura pf
# cabo san lucas mx
# puerto ayora ec
# taolanaro mg
# portland au
# atuona pf
# nanortalik gl
# avarua ck
# taolanaro mg
# albany au
# kortkeros ru
# dikson ru
# weligama lk
# vyshhorod ua
# provideniya ru
# hobart au
# arlit ne
# belushya guba ru
# hobart au
# atasu kz
# new norfolk au
# sola vu
# avarua ck
# vaitupu wf
# jalu ly
# albany au
# basoko cd
# galesong id
# mataura pf
# rikitea pf
# hilo us
# shimoda jp
# rikitea pf
# minab ir
# new norfolk au
# punta arenas cl
# bethel us
# barrow us
# tsihombe mg
# sitka us
# bolungarvik is
# birao cf
# tiksi ru
# alice springs au
# castro cl
# mataura pf
# mahebourg mu
# jamestown sh
# carnarvon au
# new norfolk au
# tabuk sa
# amderma ru
# castro cl
# codrington ag
# maracacume br
# lazaro cardenas mx
# sanmihaiu de campie ro
# rikitea pf
# ponta do sol cv
# east london za
# dikson ru
# saskylakh ru
# mataura pf
# houma us
# beryslav ua
# mar del plata ar
# casino au
# yellowknife ca
# georgetown sh
# qui nhon vn
# kapaa us
# mataura pf
# bluff nz
# kangundo ke
# chirilagua sv
# mataura pf
# ushuaia ar
# karratha au
# ponta do sol cv
# busselton au
# dingle ie
# rikitea pf
# port elizabeth za
# lerwick gb
# saleaula ws
# atuona pf
# castro cl
# longyearbyen sj
# poum nc
# busselton au
# castro cl
# busselton au
# avarua ck
# norman wells ca
# matadi cd
# qazanbulaq az
# rikitea pf
# thompson ca
# puerto ayora ec
# ponta do sol cv
# chokurdakh ru
# cayenne gf
# kaitangata nz
# walvis bay na
# hilo us
# lapeer us
# nemuro jp
# hilo us
# elesbao veloso br
# rikitea pf
# tuggurt dz
# rikitea pf
# busselton au
# fortuna us
# ponta do sol cv
# atar mr
# rikitea pf
# rabat ma
# sao paulo de olivenca br
# chumikan ru
# pacifica us
# coihueco cl
# dikson ru
# nyurba ru
# waitati nz
# beringovskiy ru
# bluff nz
# nishihara jp
# jamestown sh
# saldanha za
# mataura pf
# rikitea pf
# odienne ci
# troitskoye ru
# college us
# cheremkhovo ru
# achisay kz
# bambous virieux mu
# hilo us
# bluff nz
# kapaa us
# bluff nz
# westport nz
# hilo us
# bredasdorp za
# bua yai th
# punta arenas cl
# plettenberg bay za
# kirksville us
# muravlenko ru
# homer us
# oranjemund na
# asau tv
# ponta do sol cv
# hobart au
# punta arenas cl
# palabuhanratu id
# el paso co
# alofi nu
# mrirt ma
# camacha pt
# rikitea pf
# sogne no
# raudeberg no
# vaini to
# ushuaia ar
# awjilah ly
# sentyabrskiy ru
# bluff nz
# samalaeulu ws
# punta arenas cl
# haines junction ca
# butaritari ki
# marzuq ly
# ponta do sol cv
# puerto ayora ec
# mataura pf
# klaksvik fo
# rikitea pf
# esperance au
# karaul ru
# carnarvon au
# provideniya ru
# port lincoln au
# lasa cn
# hermanus za
# nago jp
# yellowknife ca
# yellowknife ca
# rabo de peixe pt
# praia cv
# chokurdakh ru
# bubaque gw
# kalomo zm
# aberfoyle gb
# albany au
# te anau nz
# hermanus za
# bambous virieux mu
# kahului us
# broome au
# palabuhanratu id
# punta arenas cl
# palabuhanratu id
# dalvik is
# tezu in
# mataura pf
# kaitangata nz
# waipawa nz
# hermanus za
# changji cn
# port alfred za
# bilibino ru
# portland au
# vaini to
# zhezkazgan kz
# krasnoselkup ru
# mataura pf
# albany au
# mapiripan co
# bluff nz
# mataura pf
# attawapiskat ca
# aksu cn
# alzamay ru
# galesong id
# ushuaia ar
# hermanus za
# jumla np
# fochabers gb
# chokurdakh ru
# port alfred za
# moree au
# adrar dz
# victoria sc
# severo-kurilsk ru
# taoudenni ml
# yellowknife ca
# idritsa ru
# saint-philippe re
# san carlos de bariloche ar
# ushuaia ar
# taolanaro mg
# pochutla mx
# saint george bm
# port lincoln au
# guerrero negro mx
# saldanha za
# talnakh ru
# broome au
# mamlyutka kz
# busselton au
# bluff nz
# ribeira grande pt
# punta arenas cl
# nanortalik gl
# bluff nz
# sinkat sd
# tura ru
# katsuura jp
# cankuzo bi
# mehamn no
# bereda so
# porto novo cv
# mahebourg mu
# rocha uy
# tabou ci
# aklavik ca
# yellowknife ca
# ancud cl
# albany au
# dikson ru
# sitka us
# east london za
# tasiilaq gl
# kapaa us
# hasaki jp
# punta arenas cl
# vestmanna fo
# belushya guba ru
# new norfolk au
# port elizabeth za
# batagay-alyta ru
# ushuaia ar
# srednekolymsk ru
# punta arenas cl
# mataura pf
# saint-augustin ca
# castro cl
# tuktoyaktuk ca
# amderma ru
# rikitea pf
# shingu jp
# robertson za
# ucluelet ca
# tuktoyaktuk ca
# hervey bay au
# east london za
# grand gaube mu
# churachandpur in
# hokitika nz
# hithadhoo mv
# ushuaia ar
# lebu cl
# capitan bado py
# mount gambier au
# saint-philippe re
# kaitangata nz
# balabac ph
# douentza ml
# kaitangata nz
# lamar us
# busselton au
# punta arenas cl
# qaanaaq gl
# port alfred za
# bluff nz
# saskylakh ru
# lufilufi ws
# pevek ru
# luanda ao
# mitsamiouli km
# port elizabeth za
# komsomolskiy ru
# ushuaia ar
# acajutla sv
# zhicheng cn
# nisia floresta br
# hobart au
# kodiak us
# nikolskoye ru
# maragogi br
# black river jm
# butaritari ki
# pisco pe
# kapaa us
# port blair in
# albany au
# cayhagan ph
# rosenberg us
# sao joao da barra br
# sao filipe cv
# ambodifototra mg
# rikitea pf
# karamay cn
# chuy uy
# gat ly
# busselton au
# port lincoln au
# ranong th
# santa maria do suacui br
# dalbandin pk
# new norfolk au
# albany au
# castro cl
# rio claro tt
# port alfred za
# saskylakh ru
# saskylakh ru
# birjand ir
# upernavik gl
# punta arenas cl
# kodiak us
# east london za
# saskylakh ru
# mataura pf
# teguldet ru
# torbay ca
# atuona pf
# punta arenas cl
# krasnyy chikoy ru
# pimentel pe
# ushuaia ar
# bara sd
# narsaq gl
# rikitea pf
# ostrovnoy ru
# road town vg
# trzebiatow pl
# new norfolk au
# thompson ca
# alice springs au
# leningradskiy ru
# jaru br
# vila velha br
# vaini to
# esperance au
# rikitea pf
# lavrentiya ru
# stornoway gb
# barrow us
# cape town za
# ushuaia ar
# kuche cn
# rikitea pf
# naze jp
# avarua ck
# kurilsk ru
# qaanaaq gl
# meulaboh id
# tuktoyaktuk ca
# faanui pf
# soure br
# rikitea pf
# preobrazheniye ru
# poum nc
# mataura pf
# thompson ca
# butaritari ki
# yangjiang cn
# hobart au
# buraydah sa
# punta arenas cl
# puerto madryn ar
# qaqortoq gl
# hermanus za
# lebu cl
# bluff nz
# sinnamary gf
# saint-philippe re
# jamestown sh
# hofn is
# saint george bm
# verkhoyansk ru
# pochutla mx
# hobart au
# punta arenas cl
# puerto ayora ec
# beringovskiy ru
# ushuaia ar
# acari pe
# balgazyn ru
# dikson ru
# sapouy bf
# hithadhoo mv
# ushuaia ar
# taolanaro mg
# buchanan lr
# albany au
# sisimiut gl
# georgetown sh
# ponta delgada pt
# college us
# tabou ci
# butaritari ki
# bluff nz
# illoqqortoormiut gl
# hilo us
# punta arenas cl
# gat ly
# sistranda no
# odienne ci
# markova ru
# avarua ck
# sao joao da barra br
# port alfred za
# dien bien vn
# bandarbeyla so
# mar del plata ar
# arraial do cabo br
# norman wells ca
# new norfolk au
# caravelas br
# port macquarie au
# saint-francois gp
# rikitea pf
# bluff nz
# port elizabeth za
# ushuaia ar
# garzon co
# half moon bay us
# hobart au
# mancheral in
# yellowknife ca
# harper lr
# atuona pf
# kosovska mitrovica rs
# tsihombe mg
# amderma ru
# santa luzia br
# bluff nz
# esperance au
# jurmala lv
# ambanja mg
# amderma ru
# port lincoln au
# puerto ayora ec
# jamestown sh
# zeya ru
# manaure co
# kuching my
# puerto ayora ec
# puerto ayora ec
# sembe cg
# sinnamary gf
# luena ao
# nizhneyansk ru
# pailon bo
# fortuna us
# boa vista br
# cape town za
# hobart au
# cortez us
# amderma ru
# busselton au
# poya nc
# la ronge ca
# kitimat ca
# yellowknife ca
# ponta do sol cv
# matagami ca
# avarua ck
# port alfred za
# nikolskoye ru
# dikson ru
# adrar dz
# punta arenas cl
# banda aceh id
# berbera so
# grand river south east mu
# port elizabeth za
# rikitea pf
# upernavik gl
# vaitupu wf
# busselton au
# hasaki jp
# punta arenas cl
# taolanaro mg
# punta arenas cl
# longyearbyen sj
# ushuaia ar
# rikitea pf
# berlevag no
# port blair in
# busselton au
# severo-yeniseyskiy ru
# gimli ca
# dharchula in
# tolaga bay nz
# mala vyska ua
# bluff nz
# arraial do cabo br
# kenai us
# norman wells ca
# port macquarie au
# rikitea pf
# cherskiy ru
# castro cl
# atuona pf
# candawaga ph
# kapaa us
# ushuaia ar
# ishigaki jp
# busselton au
# champerico gt
# sao felix do xingu br
# grindavik is
# pacific grove us
# avarua ck
# faya td
# luderitz na
# dongsheng cn
# castro cl
# hilo us
# arraial do cabo br
# namibe ao
# gremyachye ru
# rikitea pf
# taolanaro mg
# hermanus za
# rikitea pf
# chokurdakh ru
# cidreira br
# amapa br
# ponta do sol cv
# muros es
# cidreira br
# beboto td
# cayenne gf
# busselton au
# wrzesnia pl
# mataura pf
# vaini to
# jamestown sh
# albany au
# belushya guba ru
# illoqqortoormiut gl
# laktasi ba
# illoqqortoormiut gl
# amderma ru
# saint george bm
# launceston au
# karoi zw
# mataura pf
# kapaa us
# udalguri in
# bimbo cf
# ushuaia ar
# yellowknife ca
# sisimiut gl
# punta arenas cl
# taburbah tn
# port alfred za
# tasiilaq gl
# amderma ru
# saint-philippe re
# saint-augustin ca
# camacha pt
# klamath falls us
# paka my
# jamestown sh
# kodiak us
# yalchiki ru
# constitucion mx
# faanui pf
# mataura pf
# kapaa us
# busselton au
# nikolskoye ru
# mongu zm
# mys shmidta ru
# busselton au
# kamenskoye ru
# rikitea pf
# mataura pf
# saint-joseph re
# ushuaia ar
# rikitea pf
# amderma ru
# klaksvik fo
# kyaikto mm
# sentyabrskiy ru
# east london za
# khatanga ru
# puerto ayora ec
# butaritari ki
# punta arenas cl
# taolanaro mg
# busselton au
# olavarria ar
# albany au
# nizhneyansk ru
# palabuhanratu id
# hermanus za
# bolshoye sorokino ru
# tsihombe mg
# albany au
# bredasdorp za
# zyryanka ru
# dingle ie
# punta arenas cl
# san patricio mx
# busselton au
# vaini to
# huarmey pe
# atuona pf
# bethel us
# salon-de-provence fr
# honiara sb
# ushuaia ar
# stornoway gb
# samusu ws
# vuktyl ru
# rikitea pf
# puerto ayora ec
# kahului us
# hithadhoo mv
# albany au
# ngunguru nz
# taolanaro mg
# kenai us
# awjilah ly
# ushuaia ar
# busselton au
# kuche cn
# one hundred mile house ca
# haines junction ca
# albany au
# castro cl
# umm jarr sd
# konstantinovka ru
# hobart au
# puerto ayora ec
# doha qa
# aswan eg
# ribeira grande pt
# avarua ck
# bluff nz
# hermanus za
# hilo us
# busselton au
# pevek ru
# banfora bf
# rikitea pf
# chaiyaphum th
# rikitea pf
# hovd mn
# rikitea pf
# kandi bj
# puerto ayora ec
# laguna br
# busselton au
# grindavik is
# ushuaia ar
# punta arenas cl
# ushuaia ar
# kruisfontein za
# victoria sc
# pinerovka ru
# mataura pf
# wasilla us
# modasa in
# isangel vu
# san patricio mx
# kalemie cd
# muisne ec
# arraial do cabo br
# illoqqortoormiut gl
# nantucket us
# ushuaia ar
# saint-philippe re
# fort nelson ca
# karratha au
# bambous virieux mu
# jamestown sh
# aljezur pt
# souillac mu
# hilo us
# caravelas br
# sao felix do xingu br
# arraial do cabo br
# taolanaro mg
# ilulissat gl
# mount darwin zw
# mataura pf
# tamala ru
# namibe ao
# marzuq ly
# severo-kurilsk ru
# excelsior springs us
# ekibastuz kz
# cayenne gf
# baglan af
# aporawan ph
# castro cl
# hobart au
# goroka pg
# bolungarvik is
# dudinka ru
# grand river south east mu
# norman wells ca
# albany au
# severo-kurilsk ru
# port macquarie au
# puerto ayora ec
# mataura pf
# mataura pf
# saskylakh ru
# kruisfontein za
# aranjuez es
# tuktoyaktuk ca
# dibaya cd
# ribeira grande pt
# port alfred za
# husavik is
# jamestown sh
# ushuaia ar
# vestmannaeyjar is
# sao jose da coroa grande br
# urumqi cn
# jamestown sh

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
print(url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=fcd05be0edd6fd91056ed9f140fddd5a

# %%
# Create an endpoint URL for a city.
city_url = url + "&q=" + "Boston"
print(city_url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=fcd05be0edd6fd91056ed9f140fddd5a&q=Boston

# %%
# Make a 'Get' request for the city weather.
city_weather = requests.get(city_url)
city_weather
# Out:
# <Response [200]>

# %%
city_weather.status_code
# Out:
# 200

# %%
# Create an endpoint URL for a city.
city_url = url + "&q=" + "Bston"
city_weather = requests.get(city_url)
city_weather
# Out:
# <Response [404]>

# %%
# Create an endpoint URL for a city.
city_url = url + "&q=" + "Boston"
city_weather = requests.get(city_url)
city_weather
# Out:
# <Response [200]>

# %%
# Get the text of the 'Get' request.
city_weather.text
# Out:
# '{"coord":{"lon":-71.06,"lat":42.36},"weather":[{"id":501,"main":"Rain","description":"moderate rain","icon":"10d"}],"base":"stations","main":{"temp":76.32,"feels_like":76.82,"temp_min":73,"temp_max":80.01,"pressure":1016,"humidity":88},"visibility":16093,"wind":{"speed":14.99,"deg":70},"rain":{"1h":1.4},"clouds":{"all":90},"dt":1594413675,"sys":{"type":1,"id":3486,"country":"US","sunrise":1594372624,"sunset":1594426912},"timezone":-14400,"id":4930956,"name":"Boston","cod":200}'

# %%
# Get the JSON text of the 'Get' request.
city_weather.json()
# Out:
# {'coord': {'lon': -71.06, 'lat': 42.36},
#  'weather': [{'id': 501,
#    'main': 'Rain',
#    'description': 'moderate rain',
#    'icon': '10d'}],
#  'base': 'stations',
#  'main': {'temp': 76.32,
#   'feels_like': 76.82,
#   'temp_min': 73,
#   'temp_max': 80.01,
#   'pressure': 1016,
#   'humidity': 88},
#  'visibility': 16093,
#  'wind': {'speed': 14.99, 'deg': 70},
#  'rain': {'1h': 1.4},
#  'clouds': {'all': 90},
#  'dt': 1594413675,
#  'sys': {'type': 1,
#   'id': 3486,
#   'country': 'US',
#   'sunrise': 1594372624,
#   'sunset': 1594426912},
#  'timezone': -14400,
#  'id': 4930956,
#  'name': 'Boston',
#  'cod': 200}

# %%
# Create an endpoint URL for a city.
city_url = url + "&q=" + "Boston"
city_weather = requests.get(city_url)
if city_weather.status_code == 200:
    print(f"City Weather found.")
else:
    print(f"City weather not found.")
# Out:
# City Weather found.

# %%
# Create an endpoint URL for a city.
city_url = url + "&q=" + "Bston"
city_weather = requests.get(city_url)
if city_weather.json():
    print(f"City Weather found.")
else:
    print(f"City weather not found.")
# Out:
# City Weather found.

# %%
# Create an endpoint URL for a city.
city_url = url + "&q=" + "Boston"
city_weather = requests.get(city_url)
city_weather.json()
# Out:
# {'coord': {'lon': -71.06, 'lat': 42.36},
#  'weather': [{'id': 501,
#    'main': 'Rain',
#    'description': 'moderate rain',
#    'icon': '10d'}],
#  'base': 'stations',
#  'main': {'temp': 76.32,
#   'feels_like': 76.82,
#   'temp_min': 73,
#   'temp_max': 80.01,
#   'pressure': 1016,
#   'humidity': 88},
#  'visibility': 16093,
#  'wind': {'speed': 14.99, 'deg': 70},
#  'rain': {'1h': 1.4},
#  'clouds': {'all': 90},
#  'dt': 1594413675,
#  'sys': {'type': 1,
#   'id': 3486,
#   'country': 'US',
#   'sunrise': 1594372624,
#   'sunset': 1594426912},
#  'timezone': -14400,
#  'id': 4930956,
#  'name': 'Boston',
#  'cod': 200}

# %%
# Get the JSON data.
boston_data = city_weather.json()

# %%
boston_data['sys']
# Out:
# {'type': 1,
#  'id': 3486,
#  'country': 'US',
#  'sunrise': 1594372624,
#  'sunset': 1594426912}

# %%
boston_data['sys']['country']
# Out:
# 'US'

# %%
boston_data["dt"]
# Out:
# 1594413675

# %%
lat = boston_data["coord"]["lat"]
lng = boston_data["coord"]["lon"]
max_temp = boston_data["main"]["temp_max"]
humidity = boston_data["main"]["humidity"]
clouds = boston_data["clouds"]["all"]
wind = boston_data["wind"]["speed"]
print(lat, lng, max_temp, humidity, clouds, wind)
# Out:
# 42.36 -71.06 80.01 88 90 14.99

# %%
# Import the datetime module from the datetime library.
from datetime import datetime
# Get the date from the JSON file.
date = boston_data["dt"]
# Convert the UTC date to a date format with year, month, day, hours, minutes, and seconds.
datetime.utcfromtimestamp(date)
# Out:
# datetime.datetime(2020, 7, 10, 20, 41, 15)

# %%
datetime.utcfromtimestamp(date).strftime('%Y-%m-%d %H:%M:%S')
# Out:
# '2020-07-10 20:41:15'

# %%
# Import the time module.
import time
# Get today's date in seconds.
today = time.time()
today
# Out:
# 1594414049.7798724

# %%
today = time.strftime("%x")
today
# Out:
# '07/10/20'

# %%
# Build the scatter plot for latitude vs. max temperature.
plt.scatter(lat,
            max_temp,
            edgecolor="black", linewidths=1, marker="o",
            alpha=0.8, label="Cities")

# Incorporate the other graph properties.
plt.title(f"City Latitude vs. Max Temperature "+ time.strftime("%x"))
plt.ylabel("Max Temperature (F)")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure.
plt.savefig("weather_data/Fig1.png")

# Show plot.
plt.show()

# %%
# Build the scatter plots for latitude vs. humidity.
plt.scatter(lat,
            humidity,
            edgecolor="black", linewidths=1, marker="o",
            alpha=0.8, label="Cities")

# Incorporate the other graph properties.
plt.title(f"City Latitude vs. Humidity "+ time.strftime("%x"))
plt.ylabel("Humidity (%)")
plt.xlabel("Latitude")
plt.grid(True)
# Save the figure.
plt.savefig("weather_data/Fig2.png")
# Show plot.
plt.show()

# %%
# Build the scatter plots for latitude vs. cloudiness.
plt.scatter(lat,
            clouds,
            edgecolor="black", linewidths=1, marker="o",
            alpha=0.8, label="Cities")

# Incorporate the other graph properties.
plt.title(f"City Latitude vs. Cloudiness (%) "+ time.strftime("%x"))
plt.ylabel("Cloudiness (%)")
plt.xlabel("Latitude")
plt.grid(True)
# Save the figure.
plt.savefig("weather_data/Fig3.png")
# Show plot.
plt.show()

# %%
# Build the scatter plots for latitude vs. wind speed.
plt.scatter(lat,
            wind,
            edgecolor="black", linewidths=1, marker="o",
            alpha=0.8, label="Cities")

# Incorporate the other graph properties.
plt.title(f"City Latitude vs. Wind Speed "+ time.strftime("%x"))
plt.ylabel("Wind Speed (mph)")
plt.xlabel("Latitude")
plt.grid(True)
# Save the figure.
plt.savefig("weather_data/Fig4.png")
# Show plot.
plt.show()

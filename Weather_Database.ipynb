# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import gmaps

# Import the random module.
import random


# Use the citipy module to determine city based on latitude and longitude.
from citipy import citipy

# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)
lat_lngs 

# Import the requests library.
import requests

# Import the API key and G Key.
from config import weather_api_key
from config import g_key

# Import the datetime module from the datetime library.
from datetime import datetime

# Import linear regression from the SciPy stats module.
from scipy.stats import linregress

# %%
random.randint(-90,90)
# Out:
# -62

# %%
random.random()
# Out:
# 0.2811446367714171

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 583

# %%
# Starting URL for Weather Map API Call.

url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

print(url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=fcd05be0edd6fd91056ed9f140fddd5a

# %%
# Create an empty list to hold the weather data.
city_data = []

# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in our list.
for i in range(len(cities)):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + "i"
# Out:
# Beginning Data Retrieval
# -----------------------------

# %%
# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    
    # Add 1 to the record count.
    record_count += 1
    
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_description = city_weather["weather"][0]["description"]
        
        try:    
            city_rain = city_weather["rain"]["1h"]
        except KeyError:
            city_rain = 0
            
        try:  
            city_snow = city_weather["snow"]["1h"]
        except KeyError:
            city_snow=0
       
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description": city_description,
                          "Rain Inches": city_rain,
                          "Snow Inches": city_snow})
                        
    # If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Processing Record 1 of Set 12 | puerto ayora
# Processing Record 2 of Set 12 | ancud
# Processing Record 3 of Set 12 | shitanjing
# Processing Record 4 of Set 12 | belushya guba
# City not found. Skipping...
# Processing Record 5 of Set 12 | fuling
# Processing Record 6 of Set 12 | topeka
# Processing Record 7 of Set 12 | albany
# Processing Record 8 of Set 12 | hasaki
# Processing Record 9 of Set 12 | hobart
# Processing Record 10 of Set 12 | avarua
# Processing Record 11 of Set 12 | jamestown
# Processing Record 12 of Set 12 | poykovskiy
# Processing Record 13 of Set 12 | hilo
# Processing Record 14 of Set 12 | lebu
# Processing Record 15 of Set 12 | ondangwa
# Processing Record 16 of Set 12 | ushuaia
# Processing Record 17 of Set 12 | tomatlan
# Processing Record 18 of Set 12 | bloemfontein
# Processing Record 19 of Set 12 | siyabuswa
# Processing Record 20 of Set 12 | itarema
# Processing Record 21 of Set 12 | manaure
# Processing Record 22 of Set 12 | palabuhanratu
# City not found. Skipping...
# Processing Record 23 of Set 12 | yorosso
# Processing Record 24 of Set 12 | bredasdorp
# Processing Record 25 of Set 12 | gweta
# Processing Record 26 of Set 12 | bubaque
# Processing Record 27 of Set 12 | freetown
# Processing Record 28 of Set 12 | gasa
# Processing Record 29 of Set 12 | atuona
# Processing Record 30 of Set 12 | butaritari
# Processing Record 31 of Set 12 | chokurdakh
# Processing Record 32 of Set 12 | port elizabeth
# Processing Record 33 of Set 12 | ahvaz
# Processing Record 34 of Set 12 | bethel
# Processing Record 35 of Set 12 | rikitea
# Processing Record 36 of Set 12 | port alfred
# Processing Record 37 of Set 12 | kavieng
# Processing Record 38 of Set 12 | dong hoi
# Processing Record 39 of Set 12 | broome
# Processing Record 40 of Set 12 | norman wells
# Processing Record 41 of Set 12 | komsomolskiy
# Processing Record 42 of Set 12 | camacha
# Processing Record 43 of Set 12 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 44 of Set 12 | kungurtug
# Processing Record 45 of Set 12 | yulara
# Processing Record 46 of Set 12 | dikson
# Processing Record 47 of Set 12 | san cristobal
# Processing Record 48 of Set 12 | yellowknife
# Processing Record 49 of Set 12 | samusu
# City not found. Skipping...
# Processing Record 50 of Set 12 | tazovskiy
# Processing Record 1 of Set 13 | adrar
# Processing Record 2 of Set 13 | leningradskiy
# Processing Record 3 of Set 13 | vaini
# Processing Record 4 of Set 13 | kahului
# Processing Record 5 of Set 13 | tasiilaq
# Processing Record 6 of Set 13 | nanortalik
# Processing Record 7 of Set 13 | saskylakh
# Processing Record 8 of Set 13 | coahuayana
# Processing Record 9 of Set 13 | oga
# Processing Record 10 of Set 13 | tuatapere
# Processing Record 11 of Set 13 | ciudad bolivar
# Processing Record 12 of Set 13 | nikolskoye
# Processing Record 13 of Set 13 | new norfolk
# Processing Record 14 of Set 13 | richards bay
# Processing Record 15 of Set 13 | saldanha
# Processing Record 16 of Set 13 | busselton
# Processing Record 17 of Set 13 | kapaa
# Processing Record 18 of Set 13 | provideniya
# Processing Record 19 of Set 13 | pafos
# Processing Record 20 of Set 13 | payson
# Processing Record 21 of Set 13 | jining
# Processing Record 22 of Set 13 | dossor
# Processing Record 23 of Set 13 | constitucion
# Processing Record 24 of Set 13 | cayenne
# Processing Record 25 of Set 13 | qaanaaq
# Processing Record 26 of Set 13 | arraial do cabo
# Processing Record 27 of Set 13 | punta arenas
# Processing Record 28 of Set 13 | cape town
# Processing Record 29 of Set 13 | kodiak
# Processing Record 30 of Set 13 | dinsor
# City not found. Skipping...
# Processing Record 31 of Set 13 | mys shmidta
# City not found. Skipping...
# Processing Record 32 of Set 13 | atar
# Processing Record 33 of Set 13 | taolanaro
# City not found. Skipping...
# Processing Record 34 of Set 13 | dayong
# Processing Record 35 of Set 13 | stanari
# Processing Record 36 of Set 13 | mayo
# Processing Record 37 of Set 13 | bluff
# Processing Record 38 of Set 13 | tiksi
# Processing Record 39 of Set 13 | upernavik
# Processing Record 40 of Set 13 | ustye
# Processing Record 41 of Set 13 | fougamou
# Processing Record 42 of Set 13 | dryden
# Processing Record 43 of Set 13 | hirara
# Processing Record 44 of Set 13 | cabo san lucas
# Processing Record 45 of Set 13 | arauca
# Processing Record 46 of Set 13 | rocha
# Processing Record 47 of Set 13 | barrow
# Processing Record 48 of Set 13 | arlit
# Processing Record 49 of Set 13 | gravdal
# Processing Record 50 of Set 13 | gat
# Processing Record 1 of Set 14 | vitorino freire
# Processing Record 2 of Set 14 | torbay
# Processing Record 3 of Set 14 | east london
# Processing Record 4 of Set 14 | porterville
# Processing Record 5 of Set 14 | karbinci
# Processing Record 6 of Set 14 | pio xii
# Processing Record 7 of Set 14 | tumannyy
# City not found. Skipping...
# Processing Record 8 of Set 14 | katsuura
# Processing Record 9 of Set 14 | middle island
# Processing Record 10 of Set 14 | daru
# Processing Record 11 of Set 14 | narsaq
# Processing Record 12 of Set 14 | pangody
# Processing Record 13 of Set 14 | nunkini
# Processing Record 14 of Set 14 | kawambwa
# Processing Record 15 of Set 14 | qaqortoq
# Processing Record 16 of Set 14 | mahebourg
# Processing Record 17 of Set 14 | codrington
# Processing Record 18 of Set 14 | urdoma
# Processing Record 19 of Set 14 | port hardy
# Processing Record 20 of Set 14 | westpunt
# City not found. Skipping...
# Processing Record 21 of Set 14 | mataura
# Processing Record 22 of Set 14 | castro
# Processing Record 23 of Set 14 | khatanga
# Processing Record 24 of Set 14 | halalo
# City not found. Skipping...
# Processing Record 25 of Set 14 | marcona
# City not found. Skipping...
# Processing Record 26 of Set 14 | ponta do sol
# Processing Record 27 of Set 14 | moron
# Processing Record 28 of Set 14 | pacific grove
# Processing Record 29 of Set 14 | muros
# Processing Record 30 of Set 14 | gurupi
# Processing Record 31 of Set 14 | hermanus
# Processing Record 32 of Set 14 | horqueta
# Processing Record 33 of Set 14 | lagoa
# Processing Record 34 of Set 14 | hoima
# Processing Record 35 of Set 14 | attawapiskat
# City not found. Skipping...
# Processing Record 36 of Set 14 | bandarbeyla
# Processing Record 37 of Set 14 | haines junction
# Processing Record 38 of Set 14 | mergui
# City not found. Skipping...
# Processing Record 39 of Set 14 | ajdabiya
# Processing Record 40 of Set 14 | severo-kurilsk
# Processing Record 41 of Set 14 | saint george
# Processing Record 42 of Set 14 | hofn
# Processing Record 43 of Set 14 | mana
# Processing Record 44 of Set 14 | kichmengskiy gorodok
# Processing Record 45 of Set 14 | korla
# Processing Record 46 of Set 14 | dingle
# Processing Record 47 of Set 14 | biak
# Processing Record 48 of Set 14 | victoria
# Processing Record 49 of Set 14 | ribeira grande
# Processing Record 50 of Set 14 | ulladulla
# Processing Record 1 of Set 15 | dongsheng
# Processing Record 2 of Set 15 | chubbuck
# Processing Record 3 of Set 15 | gizo
# Processing Record 4 of Set 15 | husavik
# Processing Record 5 of Set 15 | ribas do rio pardo
# Processing Record 6 of Set 15 | livramento
# Processing Record 7 of Set 15 | umzimvubu
# City not found. Skipping...
# Processing Record 8 of Set 15 | olafsvik
# Processing Record 9 of Set 15 | sri aman
# Processing Record 10 of Set 15 | novyy urengoy
# Processing Record 11 of Set 15 | mount gambier
# Processing Record 12 of Set 15 | tuktoyaktuk
# Processing Record 13 of Set 15 | tera
# Processing Record 14 of Set 15 | westport
# Processing Record 15 of Set 15 | thayetmyo
# Processing Record 16 of Set 15 | charters towers
# Processing Record 17 of Set 15 | carnarvon
# Processing Record 18 of Set 15 | gorno-chuyskiy
# City not found. Skipping...
# Processing Record 19 of Set 15 | raudeberg
# Processing Record 20 of Set 15 | yulin
# Processing Record 21 of Set 15 | atambua
# Processing Record 22 of Set 15 | seoul
# Processing Record 23 of Set 15 | karratha
# Processing Record 24 of Set 15 | barentsburg
# City not found. Skipping...
# Processing Record 25 of Set 15 | hamilton
# Processing Record 26 of Set 15 | lethem
# Processing Record 27 of Set 15 | cockburn town
# Processing Record 28 of Set 15 | chicama
# Processing Record 29 of Set 15 | thompson
# Processing Record 30 of Set 15 | mkushi
# Processing Record 31 of Set 15 | krasnokamensk
# Processing Record 32 of Set 15 | nouna
# Processing Record 33 of Set 15 | parrita
# Processing Record 34 of Set 15 | senanga
# Processing Record 35 of Set 15 | egvekinot
# Processing Record 36 of Set 15 | ndele
# Processing Record 37 of Set 15 | port lincoln
# Processing Record 38 of Set 15 | ust-omchug
# Processing Record 39 of Set 15 | cortez
# Processing Record 40 of Set 15 | qasigiannguit
# Processing Record 41 of Set 15 | srandakan
# Processing Record 42 of Set 15 | bengkulu
# Processing Record 43 of Set 15 | embonas
# Processing Record 44 of Set 15 | ruatoria
# City not found. Skipping...
# Processing Record 45 of Set 15 | panguna
# Processing Record 46 of Set 15 | sampang
# Processing Record 47 of Set 15 | lorengau
# Processing Record 48 of Set 15 | tautira
# Processing Record 49 of Set 15 | voi
# Processing Record 50 of Set 15 | bongandanga
# Processing Record 1 of Set 16 | saint-philippe
# Processing Record 2 of Set 16 | isla vista
# Processing Record 3 of Set 16 | ust-nera
# Processing Record 4 of Set 16 | esperance
# Processing Record 5 of Set 16 | liverpool
# Processing Record 6 of Set 16 | hithadhoo
# Processing Record 7 of Set 16 | monrovia
# Processing Record 8 of Set 16 | fruitvale
# Processing Record 9 of Set 16 | fort wellington
# Processing Record 10 of Set 16 | rungata
# City not found. Skipping...
# Processing Record 11 of Set 16 | souillac
# Processing Record 12 of Set 16 | sundsvall
# Processing Record 13 of Set 16 | port moresby
# Processing Record 14 of Set 16 | merauke
# Processing Record 15 of Set 16 | bambous virieux
# Processing Record 16 of Set 16 | jujuy
# City not found. Skipping...
# Processing Record 17 of Set 16 | prince rupert
# Processing Record 18 of Set 16 | guerrero negro
# Processing Record 19 of Set 16 | louisbourg
# City not found. Skipping...
# Processing Record 20 of Set 16 | vuktyl
# Processing Record 21 of Set 16 | salym
# Processing Record 22 of Set 16 | matara
# Processing Record 23 of Set 16 | vallenar
# Processing Record 24 of Set 16 | vanimo
# Processing Record 25 of Set 16 | ulaangom
# Processing Record 26 of Set 16 | chaiya
# Processing Record 27 of Set 16 | isiro
# Processing Record 28 of Set 16 | cedar city
# Processing Record 29 of Set 16 | melville
# Processing Record 30 of Set 16 | clyde river
# Processing Record 31 of Set 16 | beloha
# Processing Record 32 of Set 16 | alofi
# Processing Record 33 of Set 16 | la ronge
# Processing Record 34 of Set 16 | mangrol
# Processing Record 35 of Set 16 | xapuri
# Processing Record 36 of Set 16 | caohai
# Processing Record 37 of Set 16 | nizhniy ufaley
# Processing Record 38 of Set 16 | harseni
# Processing Record 39 of Set 16 | baykit
# Processing Record 40 of Set 16 | yuanlin
# Processing Record 41 of Set 16 | santa rosa
# Processing Record 42 of Set 16 | sisimiut
# Processing Record 43 of Set 16 | vila do maio
# Processing Record 44 of Set 16 | anadyr
# Processing Record 45 of Set 16 | barranca
# Processing Record 46 of Set 16 | bam
# Processing Record 47 of Set 16 | khandbari
# Processing Record 48 of Set 16 | koutsouras
# Processing Record 49 of Set 16 | coos bay
# Processing Record 50 of Set 16 | bone
# Processing Record 1 of Set 17 | lolua
# City not found. Skipping...
# Processing Record 2 of Set 17 | guapore
# Processing Record 3 of Set 17 | solnechnyy
# Processing Record 4 of Set 17 | serta
# Processing Record 5 of Set 17 | awbari
# Processing Record 6 of Set 17 | cherskiy
# Processing Record 7 of Set 17 | salalah
# Processing Record 8 of Set 17 | axim
# Processing Record 9 of Set 17 | cabedelo
# Processing Record 10 of Set 17 | sarakhs
# Processing Record 11 of Set 17 | georgetown
# Processing Record 12 of Set 17 | kununurra
# Processing Record 13 of Set 17 | saint anthony
# Processing Record 14 of Set 17 | neiafu
# Processing Record 15 of Set 17 | grand river south east
# City not found. Skipping...
# Processing Record 16 of Set 17 | nome
# Processing Record 17 of Set 17 | sao jose da coroa grande
# Processing Record 18 of Set 17 | sitka
# Processing Record 19 of Set 17 | yertarskiy
# Processing Record 20 of Set 17 | balingasay
# Processing Record 21 of Set 17 | khilok
# Processing Record 22 of Set 17 | srednekolymsk
# Processing Record 23 of Set 17 | nizhneyansk
# City not found. Skipping...
# Processing Record 24 of Set 17 | avera
# Processing Record 25 of Set 17 | aklavik
# Processing Record 26 of Set 17 | okhotsk
# Processing Record 27 of Set 17 | zeya
# Processing Record 28 of Set 17 | sao joao da barra
# Processing Record 29 of Set 17 | mar del plata
# Processing Record 30 of Set 17 | zhangjiakou
# Processing Record 31 of Set 17 | tual
# Processing Record 32 of Set 17 | lakes entrance
# Processing Record 33 of Set 17 | amderma
# City not found. Skipping...
# Processing Record 34 of Set 17 | crab hill
# City not found. Skipping...
# Processing Record 35 of Set 17 | khanpur
# Processing Record 36 of Set 17 | ilulissat
# Processing Record 37 of Set 17 | siddhapur
# Processing Record 38 of Set 17 | dwarka
# Processing Record 39 of Set 17 | zyryanka
# Processing Record 40 of Set 17 | gazojak
# Processing Record 41 of Set 17 | namibe
# Processing Record 42 of Set 17 | ekhabi
# Processing Record 43 of Set 17 | nouakchott
# Processing Record 44 of Set 17 | vila velha
# Processing Record 45 of Set 17 | nizhniy odes
# Processing Record 46 of Set 17 | hambantota
# Processing Record 47 of Set 17 | lazaro cardenas
# Processing Record 48 of Set 17 | plunge
# Processing Record 49 of Set 17 | bogande
# Processing Record 50 of Set 17 | anzio
# Processing Record 1 of Set 18 | berlevag
# Processing Record 2 of Set 18 | brae
# Processing Record 3 of Set 18 | sinkat
# City not found. Skipping...
# Processing Record 4 of Set 18 | zhanaozen
# Processing Record 5 of Set 18 | itoman
# Processing Record 6 of Set 18 | zhigansk
# Processing Record 7 of Set 18 | machesney park
# Processing Record 8 of Set 18 | longyearbyen
# Processing Record 9 of Set 18 | hanzhong
# Processing Record 10 of Set 18 | longlac
# City not found. Skipping...
# Processing Record 11 of Set 18 | portland
# Processing Record 12 of Set 18 | lavrentiya
# Processing Record 13 of Set 18 | kumluca
# Processing Record 14 of Set 18 | djibo
# Processing Record 15 of Set 18 | ugoofaaru
# Processing Record 16 of Set 18 | beringovskiy
# Processing Record 17 of Set 18 | acarau
# Processing Record 18 of Set 18 | sokoni
# Processing Record 19 of Set 18 | san carlos de bariloche
# Processing Record 20 of Set 18 | kiama
# Processing Record 21 of Set 18 | tahoua
# Processing Record 22 of Set 18 | barcelona
# Processing Record 23 of Set 18 | santa maria
# Processing Record 24 of Set 18 | fortuna
# Processing Record 25 of Set 18 | ostrovnoy
# Processing Record 26 of Set 18 | mocuba
# Processing Record 27 of Set 18 | noumea
# Processing Record 28 of Set 18 | batagay
# Processing Record 29 of Set 18 | meyungs
# City not found. Skipping...
# Processing Record 30 of Set 18 | cidreira
# Processing Record 31 of Set 18 | zavyalovo
# Processing Record 32 of Set 18 | mareeba
# Processing Record 33 of Set 18 | mongu
# Processing Record 34 of Set 18 | omboue
# Processing Record 35 of Set 18 | progreso
# Processing Record 36 of Set 18 | norwich
# Processing Record 37 of Set 18 | pevek
# Processing Record 38 of Set 18 | pingliang
# Processing Record 39 of Set 18 | airai
# Processing Record 40 of Set 18 | san patricio
# Processing Record 41 of Set 18 | lyuban
# Processing Record 42 of Set 18 | antanifotsy
# Processing Record 43 of Set 18 | warqla
# City not found. Skipping...
# Processing Record 44 of Set 18 | luderitz
# Processing Record 45 of Set 18 | balaipungut
# Processing Record 46 of Set 18 | kupang
# Processing Record 47 of Set 18 | marsh harbour
# Processing Record 48 of Set 18 | hwange
# Processing Record 49 of Set 18 | faya
# Processing Record 50 of Set 18 | mackenzie
# Processing Record 1 of Set 19 | guamal
# Processing Record 2 of Set 19 | yazman
# Processing Record 3 of Set 19 | igarka
# Processing Record 4 of Set 19 | waverly
# Processing Record 5 of Set 19 | gwadar
# Processing Record 6 of Set 19 | maloshuyka
# City not found. Skipping...
# Processing Record 7 of Set 19 | snezhnogorsk
# Processing Record 8 of Set 19 | sidney
# Processing Record 9 of Set 19 | burica
# City not found. Skipping...
# Processing Record 10 of Set 19 | chuy
# Processing Record 11 of Set 19 | sidi ali
# Processing Record 12 of Set 19 | santa cruz
# Processing Record 13 of Set 19 | clarence town
# Processing Record 14 of Set 19 | araouane
# Processing Record 15 of Set 19 | kaitangata
# Processing Record 16 of Set 19 | malinyi
# Processing Record 17 of Set 19 | wukari
# Processing Record 18 of Set 19 | faanui
# Processing Record 19 of Set 19 | sumbawa
# City not found. Skipping...
# Processing Record 20 of Set 19 | yaan
# Processing Record 21 of Set 19 | lasa
# Processing Record 22 of Set 19 | panormos
# Processing Record 23 of Set 19 | margate
# Processing Record 24 of Set 19 | bani walid
# Processing Record 25 of Set 19 | kathu
# Processing Record 26 of Set 19 | kaeo
# Processing Record 27 of Set 19 | dickinson
# Processing Record 28 of Set 19 | winsum
# Processing Record 29 of Set 19 | rock springs
# Processing Record 30 of Set 19 | eufaula
# Processing Record 31 of Set 19 | alghero
# Processing Record 32 of Set 19 | nemuro
# Processing Record 33 of Set 19 | nizhniy tsasuchey
# Processing Record 34 of Set 19 | sao filipe
# Processing Record 35 of Set 19 | neuquen
# Processing Record 36 of Set 19 | vestmanna
# Processing Record 37 of Set 19 | kassala
# Processing Record 38 of Set 19 | altay
# Processing Record 39 of Set 19 | amot
# Processing Record 40 of Set 19 | kawalu
# Processing Record 41 of Set 19 | cleveland
# Processing Record 42 of Set 19 | paamiut
# Processing Record 43 of Set 19 | mildura
# Processing Record 44 of Set 19 | ganta
# Processing Record 45 of Set 19 | sur
# Processing Record 46 of Set 19 | kalianget
# Processing Record 47 of Set 19 | boa vista
# Processing Record 48 of Set 19 | play cu
# City not found. Skipping...
# Processing Record 49 of Set 19 | phan rang
# City not found. Skipping...
# Processing Record 50 of Set 19 | cumra
# Processing Record 1 of Set 20 | namatanai
# Processing Record 2 of Set 20 | tsienyane
# City not found. Skipping...
# Processing Record 3 of Set 20 | maurawan
# Processing Record 4 of Set 20 | ambulu
# Processing Record 5 of Set 20 | lujiang
# Processing Record 6 of Set 20 | iqaluit
# Processing Record 7 of Set 20 | kocevje
# Processing Record 8 of Set 20 | hobyo
# Processing Record 9 of Set 20 | bathsheba
# Processing Record 10 of Set 20 | andrews
# Processing Record 11 of Set 20 | sabang
# Processing Record 12 of Set 20 | oyama
# Processing Record 13 of Set 20 | abashiri
# Processing Record 14 of Set 20 | balimo
# City not found. Skipping...
# Processing Record 15 of Set 20 | birjand
# Processing Record 16 of Set 20 | jardim
# Processing Record 17 of Set 20 | saint-augustin
# Processing Record 18 of Set 20 | huazolotitlan
# City not found. Skipping...
# Processing Record 19 of Set 20 | kavaratti
# Processing Record 20 of Set 20 | tsihombe
# City not found. Skipping...
# Processing Record 21 of Set 20 | chumikan
# Processing Record 22 of Set 20 | kaniama
# Processing Record 23 of Set 20 | sabya
# Processing Record 24 of Set 20 | high river
# Processing Record 25 of Set 20 | villa corzo
# Processing Record 26 of Set 20 | ranchi
# Processing Record 27 of Set 20 | bonoua
# Processing Record 28 of Set 20 | mantua
# Processing Record 29 of Set 20 | kiunga
# Processing Record 30 of Set 20 | hay river
# Processing Record 31 of Set 20 | poopo
# Processing Record 32 of Set 20 | lompoc
# Processing Record 33 of Set 20 | inuvik
# Processing Record 34 of Set 20 | achisay
# City not found. Skipping...
# Processing Record 35 of Set 20 | porto novo
# Processing Record 36 of Set 20 | ixtapa
# Processing Record 37 of Set 20 | meulaboh
# Processing Record 38 of Set 20 | sorland
# Processing Record 39 of Set 20 | ishigaki
# Processing Record 40 of Set 20 | taburi
# City not found. Skipping...
# Processing Record 41 of Set 20 | batagay-alyta
# Processing Record 42 of Set 20 | papara
# Processing Record 43 of Set 20 | guangyuan
# Processing Record 44 of Set 20 | jumla
# Processing Record 45 of Set 20 | eureka
# Processing Record 46 of Set 20 | quatre cocos
# Processing Record 47 of Set 20 | morros
# Processing Record 48 of Set 20 | gympie
# Processing Record 49 of Set 20 | tema
# Processing Record 50 of Set 20 | pontianak
# Processing Record 1 of Set 21 | te anau
# Processing Record 2 of Set 21 | shenjiamen
# Processing Record 3 of Set 21 | padang
# Processing Record 4 of Set 21 | alice
# Processing Record 5 of Set 21 | auki
# Processing Record 6 of Set 21 | mackay
# Processing Record 7 of Set 21 | gomel
# Processing Record 8 of Set 21 | novikovo
# Processing Record 9 of Set 21 | vaitupu
# City not found. Skipping...
# Processing Record 10 of Set 21 | souris
# Processing Record 11 of Set 21 | khani
# Processing Record 12 of Set 21 | ginda
# Processing Record 13 of Set 21 | la rioja
# Processing Record 14 of Set 21 | kamenskoye
# City not found. Skipping...
# Processing Record 15 of Set 21 | kuche
# City not found. Skipping...
# Processing Record 16 of Set 21 | saint-pierre
# Processing Record 17 of Set 21 | praia da vitoria
# Processing Record 18 of Set 21 | iquique
# Processing Record 19 of Set 21 | ondorhaan
# City not found. Skipping...
# Processing Record 20 of Set 21 | sabha
# Processing Record 21 of Set 21 | mehamn
# Processing Record 22 of Set 21 | palmer
# Processing Record 23 of Set 21 | saleaula
# City not found. Skipping...
# Processing Record 24 of Set 21 | evensk
# Processing Record 25 of Set 21 | gollere
# City not found. Skipping...
# Processing Record 26 of Set 21 | kruisfontein
# Processing Record 27 of Set 21 | sattahip
# Processing Record 28 of Set 21 | kirakira
# Processing Record 29 of Set 21 | ola
# Processing Record 30 of Set 21 | rexburg
# Processing Record 31 of Set 21 | sorong
# Processing Record 32 of Set 21 | touros
# Processing Record 33 of Set 21 | beihai
# Processing Record 34 of Set 21 | ocos
# Processing Record 35 of Set 21 | maxixe
# Processing Record 36 of Set 21 | saint-joseph
# Processing Record 37 of Set 21 | bitung
# Processing Record 38 of Set 21 | of
# City not found. Skipping...
# Processing Record 39 of Set 21 | cap-chat
# Processing Record 40 of Set 21 | phalaborwa
# Processing Record 41 of Set 21 | marawi
# Processing Record 42 of Set 21 | sindor
# Processing Record 43 of Set 21 | kysyl-syr
# Processing Record 44 of Set 21 | conde
# Processing Record 45 of Set 21 | sosnovo-ozerskoye
# Processing Record 46 of Set 21 | labuhan
# Processing Record 47 of Set 21 | vao
# Processing Record 48 of Set 21 | rancho veloz
# Processing Record 49 of Set 21 | cedral
# Processing Record 50 of Set 21 | kodino
# Processing Record 1 of Set 22 | ordzhonikidze
# Processing Record 2 of Set 22 | pisco
# Processing Record 3 of Set 22 | bodmin
# Processing Record 4 of Set 22 | hastings
# Processing Record 5 of Set 22 | pulandian
# Processing Record 6 of Set 22 | canakkale
# Processing Record 7 of Set 22 | tegal
# Processing Record 8 of Set 22 | olinda
# Processing Record 9 of Set 22 | aleksandrov gay
# Processing Record 10 of Set 22 | beaverlodge
# Processing Record 11 of Set 22 | lalsk
# Processing Record 12 of Set 22 | ust-maya
# Processing Record 13 of Set 22 | pagudpud
# Processing Record 14 of Set 22 | cintalapa
# Processing Record 15 of Set 22 | mount isa
# Processing Record 16 of Set 22 | vardo
# Processing Record 17 of Set 22 | udachnyy
# Processing Record 18 of Set 22 | ulagan
# Processing Record 19 of Set 22 | ucluelet
# Processing Record 20 of Set 22 | sao gabriel da cachoeira
# Processing Record 21 of Set 22 | pringsewu
# Processing Record 22 of Set 22 | moreira sales
# Processing Record 23 of Set 22 | takoradi
# Processing Record 24 of Set 22 | wanning
# Processing Record 25 of Set 22 | sola
# Processing Record 26 of Set 22 | palmas
# Processing Record 27 of Set 22 | vestmannaeyjar
# Processing Record 28 of Set 22 | paradwip
# City not found. Skipping...
# Processing Record 29 of Set 22 | belmonte
# Processing Record 30 of Set 22 | xadani
# City not found. Skipping...
# Processing Record 31 of Set 22 | nkayi
# Processing Record 32 of Set 22 | quang ngai
# Processing Record 33 of Set 22 | khash
# Processing Record 34 of Set 22 | saint-francois
# Processing Record 35 of Set 22 | klaksvik
# Processing Record 36 of Set 22 | coaticook
# Processing Record 37 of Set 22 | roebourne
# Processing Record 38 of Set 22 | fereydun kenar
# Processing Record 39 of Set 22 | havre
# Processing Record 40 of Set 22 | tessalit
# Processing Record 41 of Set 22 | apam
# Processing Record 42 of Set 22 | bogotol
# Processing Record 43 of Set 22 | odweyne
# Processing Record 44 of Set 22 | goderich
# Processing Record 45 of Set 22 | wahran
# City not found. Skipping...
# Processing Record 46 of Set 22 | okha
# Processing Record 47 of Set 22 | port blair
# Processing Record 48 of Set 22 | oreanda
# City not found. Skipping...
# Processing Record 49 of Set 22 | vostok
# Processing Record 50 of Set 22 | balykshi
# City not found. Skipping...
# Processing Record 1 of Set 23 | porkhov
# Processing Record 2 of Set 23 | kampene
# Processing Record 3 of Set 23 | kashi
# Processing Record 4 of Set 23 | puerto baquerizo moreno
# Processing Record 5 of Set 23 | agadez
# Processing Record 6 of Set 23 | nishihara
# Processing Record 7 of Set 23 | nizhneangarsk
# Processing Record 8 of Set 23 | acapulco
# Processing Record 9 of Set 23 | lifford
# Processing Record 10 of Set 23 | paragominas
# Processing Record 11 of Set 23 | kudahuvadhoo
# Processing Record 12 of Set 23 | shar
# Processing Record 13 of Set 23 | geraldton
# Processing Record 14 of Set 23 | adjumani
# Processing Record 15 of Set 23 | zychlin
# Processing Record 16 of Set 23 | shimoda
# Processing Record 17 of Set 23 | isangel
# Processing Record 18 of Set 23 | simao
# Processing Record 19 of Set 23 | rantauprapat
# Processing Record 20 of Set 23 | aykhal
# Processing Record 21 of Set 23 | lata
# Processing Record 22 of Set 23 | sentyabrskiy
# City not found. Skipping...
# Processing Record 23 of Set 23 | isla mujeres
# Processing Record 24 of Set 23 | eagle pass
# Processing Record 25 of Set 23 | hvide sande
# Processing Record 26 of Set 23 | usinsk
# Processing Record 27 of Set 23 | bhola
# Processing Record 28 of Set 23 | rio grande
# Processing Record 29 of Set 23 | rincon
# Processing Record 30 of Set 23 | longhua
# Processing Record 31 of Set 23 | christchurch
# Processing Record 32 of Set 23 | mountain home
# Processing Record 33 of Set 23 | colares
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
len(city_data)
# Out:
# 530

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#            City Country    Lat     Lng  Max Temp  Humidity  Cloudiness  \
# 0  Puerto Ayora      EC  -0.74  -90.35     70.00        86          88
# 1         Ancud      CL -41.87  -73.82     46.99        81          20
# 2    Shitanjing      CN  39.23  106.34     66.15        70           0
# 3        Fuling      CN  29.70  107.39     75.58        93         100
# 4        Topeka      US  39.05  -95.68     87.80        43           1
# 5        Albany      US  42.60  -73.97     90.00        38           7
# 6        Hasaki      JP  35.73  140.83     64.40       100          75
# 7        Hobart      AU -42.88  147.33     39.99        93          75
# 8        Avarua      CK -21.21 -159.78     69.80        94          94
# 9     Jamestown      US  42.10  -79.24     75.00        60           1
#
#    Wind Speed   Current Description  Rain Inches  Snow Inches
# 0        1.99       overcast clouds         0.00            0
# 1        4.70            few clouds         0.00            0
# 2        3.71             clear sky         0.00            0
# 3        1.50         moderate rain         1.44            0
# 4       14.99             clear sky         0.00            0
# 5        9.13             clear sky         0.00            0
# 6        6.93         broken clouds         0.00            0
# 7        9.17         broken clouds         0.00            0
# 8        6.93  heavy intensity rain         0.00            0
# 9       12.75             clear sky         0.00            0

# %%
# Create the output file (CSV).
output_data_file = "weather_data/WeatherPy_database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
